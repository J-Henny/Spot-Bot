# %% [markdown]
# ### API Initialization

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import json
import os
import csv
import time
import retrying
import pandas as pd
from surprise import Dataset, Reader, KNNBasic

#########################################################################################
#######################               INIT            ###################################
#########################################################################################
# setting API keys
# os.environ['SPOTIPY_CLIENT_ID'] = "YOUR KEY HERE"
# os.environ['SPOTIPY_CLIENT_SECRET'] = "YOUR KEY HERE"
# os.environ['SPOTIPY_REDIRECT_URI'] = "https://localhost:8888/callback"

# declaring what this app can control within a user's spotify
scope = ["user-library-read", "user-read-private", "user-library-modify", "playlist-read-private",
"playlist-read-collaborative", "user-read-currently-playing", "playlist-modify-public", "playlist-modify-private",
"user-top-read", "streaming", "user-read-recently-played", "app-remote-control"]


#Connecting to user's spotify data
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

#get top artists and tracks as json to test
top_artists = sp.current_user_top_artists(limit=50, offset=0, time_range='short_term')
top_tracks = sp.current_user_top_tracks(limit=50, offset=0, time_range='short_term')
print(top_artists)
# Out:
# C:\Users\Henze\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
# {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oifjQw72WO7Jut07fVWMy'}, 'followers': {'href': None, 'total': 0}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5oifjQw72WO7Jut07fVWMy', 'id': '5oifjQw72WO7Jut07fVWMy', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebb05f625e8f337fd8756d253f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174b05f625e8f337fd8756d253f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178b05f625e8f337fd8756d253f', 'width': 160}], 'name': 'KAYTRAMINÉ', 'popularity': 68, 'type': 'artist', 'uri': 'spotify:artist:5oifjQw72WO7Jut07fVWMy'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1wlzPS1hSNrkriIIwLFTmU'}, 'followers': {'href': None, 'total': 0}, 'genres': ['alternative hip hop', 'chill abstract hip hop', 'indie hip hop'], 'href': 'https://api.spotify.com/v1/artists/1wlzPS1hSNrkriIIwLFTmU', 'id': '1wlzPS1hSNrkriIIwLFTmU', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb799cc7ce986f2b2dd70cc6c7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174799cc7ce986f2b2dd70cc6c7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178799cc7ce986f2b2dd70cc6c7', 'width': 160}], 'name': 'MIKE', 'popularity': 53, 'type': 'artist', 'uri': 'spotify:artist:1wlzPS1hSNrkriIIwLFTmU'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vmLIa1VRY38hZoar8AyYS'}, 'followers': {'href': None, 'total': 0}, 'genres': ['indie hip hop', 'underground hip hop'], 'href': 'https://api.spotify.com/v1/artists/1vmLIa1VRY38hZoar8AyYS', 'id': '1vmLIa1VRY38hZoar8AyYS', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba1481cc895af7c11e390ad2b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a1481cc895af7c11e390ad2b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a1481cc895af7c11e390ad2b', 'width': 160}], 'name': 'Chester Watson', 'popularity': 41, 'type': 'artist', 'uri': 'spotify:artist:1vmLIa1VRY38hZoar8AyYS'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJ6QQ3Y5l0s0tn7b0arrO'}, 'followers': {'href': None, 'total': 0}, 'genres': ['alternative hip hop', 'experimental hip hop', 'industrial hip hop', 'underground hip hop'], 'href': 'https://api.spotify.com/v1/artists/6yJ6QQ3Y5l0s0tn7b0arrO', 'id': '6yJ6QQ3Y5l0s0tn7b0arrO', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb70cf26120e6f847e0fc00555', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517470cf26120e6f847e0fc00555', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17870cf26120e6f847e0fc00555', 'width': 160}], 'name': 'JPEGMAFIA', 'popularity': 68, 'type': 'artist', 'uri': 'spotify:artist:6yJ6QQ3Y5l0s0tn7b0arrO'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/17Zu03OgBVxgLxWmRUyNOJ'}, 'followers': {'href': None, 'total': 0}, 'genres': ['abstract beats', 'alternative hip hop', 'indie soul', 'instrumental hip hop', 'wonky'], 'href': 'https://api.spotify.com/v1/artists/17Zu03OgBVxgLxWmRUyNOJ', 'id': '17Zu03OgBVxgLxWmRUyNOJ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb8e0147d29ac3c4f161924696', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051748e0147d29ac3c4f161924696', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1788e0147d29ac3c4f161924696', 'width': 160}], 'name': 'Knxwledge', 'popularity': 62, 'type': 'artist', 'uri': 'spotify:artist:17Zu03OgBVxgLxWmRUyNOJ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Ng5YIxfFxELV3scQVISlB'}, 'followers': {'href': None, 'total': 0}, 'genres': ['experimental hip hop'], 'href': 'https://api.spotify.com/v1/artists/2Ng5YIxfFxELV3scQVISlB', 'id': '2Ng5YIxfFxELV3scQVISlB', 'images': [{'height': 640, 'url': 'htt ...

# %% [markdown]
# ### Helper functions
# For ease of data handling

# %%
@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_top_tracks():
    return sp.current_user_top_tracks(limit=50, offset=0, time_range='short_term')

@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_tracks(tracks):
    return sp.tracks(tracks)['tracks']

@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_audio_analysis(track_id):
    return sp.audio_analysis(track_id)['track']

@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_audio_features(track_id):
    return sp.audio_features(track_id)[0]

@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_related_artists(artist_id):
    return sp.artist_related_artists(artist_id)['artists']
    
@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_artist_albums(artist_id):
    return sp.artist_albums(artist_id)['items']

@retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
def get_album_tracks(album_id):
    return sp.album_tracks(album_id)['items']

# %%
def getTop50songs():
    ## gets the user's top 50 most listened to songs.
    top_tracks = get_top_tracks();
    ids = []
    for i in range(50):
        id_ = top_tracks['items'][i]['id']
        ids.append(id_)
    
    return ids

# %%
def top50songsDriver():
    ## gets top 50 songs, adds all necessary track data, and writes to file.
    print("Getting your top 50 most listened to songs...")
    top_50_ids = getTop50songs()
    print("Extracting data from your songs...")
    top_50_samples = generateSamples(top_50_ids)
    print("Writing to file...")
    writeLabelsToFile(rowFields(), "base")
    writeSongsToFile(top_50_samples, "base")
    print("Complete.")

# %%
def getTopArtistInfo():
    ## gets info on user's top 50 artists.
    ids = []
    names = []
    for i in range(50):
        ids.append(top_artists['items'][i]['id'])
        names.append(top_artists['items'][i]['name'])

    return ids, names

# %%
def generateSamples(tracks):
    # constructs all needed attributes from batch of tracks
    genAttributes = ['name', 'popularity', 'explicit']
    analysisAttributes =  ['num_samples', 'duration', 'offset_seconds', 'window_seconds', 'analysis_sample_rate', 'end_of_fade_in', 'start_of_fade_out', 
                'loudness', 'tempo', 'tempo_confidence', 'time_signature', 'time_signature_confidence', 'key', 'key_confidence', 'mode', 'mode_confidence']
    featureAttributes = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']
    samples = []
    
    track_chunks = [tracks[i:i+50] for i in range(0, len(tracks), 50)]
    
    for chunk in track_chunks:
        tracks_info = get_tracks(chunk)
        
        for track in tracks_info:
            sample = []
            
            sample.append(track['artists'][0]['name'])

            for att in genAttributes:
                if att in track:
                    sample.append(track[att])
                else:
                    sample.append(None)
                
            track_id = track['id']

            analysis = get_audio_analysis(track_id)
            time.sleep(2.5) # avoiding rate limiting
            for att in analysisAttributes:
                if analysis and att in analysis:
                    sample.append(analysis[att])
                else:
                    sample.append(None)

            features = get_audio_features(track_id)
            time.sleep(2.5) # avoiding rate limiting
            for att in featureAttributes:
                if features and att in features:
                    sample.append(features[att])
                else:
                    sample.append(None)

            samples.append(sample)
    return samples

# %%
def rowFields():
    return ['id', 'artist_name(s)', 'song_name', 'popularity', 'explicit?',
        'num_samples', 'duration', 'offset_seconds', 'window_seconds', 
        'analysis_sample_rate', 'end_of_fade_in', 'start_of_fade_out', 
        'loudness', 'tempo', 'tempo_confidence', 'time_signature', 
        'time_signature_confidence', 'key', 'key_confidence', 'mode', 
        'mode_confidence', 'danceability', 'energy', 'speechiness', 
        'acousticness', 'instrumentalness', 'liveness', 'valence']

# %%
def writeLabelsToFile(fields, fileType):
    filename = "Spotify_" + fileType + "_data.txt"
    with open(filename, 'a', encoding="utf-8") as file:
        write = csv.writer(file)
        write.writerow(fields)

# %%
def writeSongsToFile(data, fileType):
    filename = "Spotify_" + fileType + "_data.txt"
    with open(filename, 'a', encoding="utf-8") as file:
        write = csv.writer(file)
        for sample in data:
            write.writerow(sample)

# %%
def searchRelated(artists_to_search, artists_searched):
    ## takes a list of artists and returns all related artists from each artist.
    newArtistIds = []
    newArtistNames = []

    for i in artists_to_search:
        related_artists = get_related_artists(i);
        for j in range(len(related_artists)):
            if related_artists[j]['id'] not in artists_to_search and related_artists[j]['id'] not in artists_searched:
                newArtistIds.append(related_artists[j]['id'])
                newArtistNames.append(related_artists[j]['name'])

    return newArtistIds, newArtistNames

# %%
def baseScrape():
    """Takes top 50 artists, scrapes related artists from all 50."""
    artists_ids = []
    artists_names = []
    print("Performing base scrape...")
    for i in range(50):
        artist_id = top_tracks['items'][i]['artists'][0]['id']
        artists_searching = []
        artists_searching.append(artist_id)
        if i == 0:
            artists_ids.append(artist_id)
            artists_names.append(top_tracks['items'][i]['artists'][0]['name'])
            searchedIds, searchedNames = searchRelated(artists_searching,[])
        else:
            searchedIds, searchedNames = searchRelated(artists_searching, artists_ids)

        for j in range(len(searchedNames)):
            artists_ids.append(searchedIds[j])
            artists_names.append(searchedNames[j])

    return artists_ids, artists_names

# %%
def recursiveScrape(ids, names, step):
    """Takes artists/ids from base scrape, and computes a recursive scrape for x amount of steps.
        *** Not currently in use *** """

    if step == 0:
        return ids, names
    else:
        for id_ in ids:
            artist_id = id_
            artists_searching = []
            artists_searching.append(artist_id)
            searchedIds, searchedNames = searchRelated(artists_searching, ids)

            for j in range(len(searchedNames)):
                ids.append(searchedIds[j])
                names.append(searchedNames[j])

        return recursiveScrape(ids, names, step-1)

# %%
def getSongsFromArtist(artist_id):
    # gets all songs from an artist
    artist_track_ids = []
    ##get album ids from artist id
    artist_albums = get_artist_albums(artist_id)
    album_ids = []
    for i in range(len(artist_albums)):
        album_id = artist_albums[i]['id']
        if album_id not in album_ids:
            album_ids.append(album_id)

            ##now have all albums from artist.
            ## get every song from every album.
                
            album_tracks = get_album_tracks(album_id)
            for j in range(len(album_tracks)):
                track_id = album_tracks[j]['id']
                print("Track id added: {}".format(track_id))
                artist_track_ids.append(track_id)
                

    return artist_track_ids

# %%
def scrapedSongsDriver(artist_ids):
    writeLabelsToFile(rowFields(), "scraped")
    for artist in artist_ids:
        print("Gathering songs from id: {}".format(artist))
        artist_tracks = getSongsFromArtist(artist)
        artist_track_samples = generateSamples(artist_tracks)
        writeSongsToFile(artist_track_samples, "scraped")

# %%
def mainScrapingDriver():
    """Stores user's songs + public scraped songs in respective files for learning + reccomending"""

    ## get top 50 artists info
    print("Getting your top artists info...")
    ids, names = getTopArtistInfo()
    for i in range(len(ids)):
        print("{} : {}".format(ids[i], names[i]))

    # Store user songs
    print("Analyzing your top 50 songs...")
    top50songsDriver() ##gets 50 most listened to songs, writes necessary track info to file

    ## Perform base artist scrape
    print("Searching for more artists...")
    scrapedArtistIds, scrapedArtistNames = baseScrape() 

    print("Artist scrape complete.")
    print(scrapedArtistNames)
    
    print("Scraping tracks from collected Artists...")
    scrapedSongsDriver(scrapedArtistIds)
    print("All tracks gathered. Proceeding to analyze and select songs...")

# %%
mainScrapingDriver()
# Out:
# Getting your top artists info...
# 2exebQUDoIoT0dXA8BcN1P : Home
# 5oifjQw72WO7Jut07fVWMy : KAYTRAMINÉ
# 1wlzPS1hSNrkriIIwLFTmU : MIKE
# 1vmLIa1VRY38hZoar8AyYS : Chester Watson
# 6qgnBH6iDM91ipVXv28OMu : KAYTRANADA
# 17Zu03OgBVxgLxWmRUyNOJ : Knxwledge
# 2Ng5YIxfFxELV3scQVISlB : B. Cool-Aid
# 6yJ6QQ3Y5l0s0tn7b0arrO : JPEGMAFIA
# 2GqaakAnuhfpY4drbXrEmL : Devonwho
# 2pAWfrd7WFF3XhVt9GooDL : MF DOOM
# 5j93hwFBNo29RJMsWvtzj8 : Zelooperz
# 7HY1ISUuRotG01FVu0PKWh : mynameisntjmack
# 0Y4inQK6OespitzD6ijMwb : Freddie Gibbs
# 39vtb2iiz3079nqfL5nfFc : billy woods
# 62v3nR2gE0z1AFSFHxKepe : ぬいぐるみクレヨン Lush Crayon
# 40ZElxHldNyvn7x8WRC6fh : Pink Siifu
# 6OjtkJDlAZzlzAydEn78cK : Bktherula
# 4DpmPt7gfAAq7WEx0E1X8s : piri
# 6P7H3ai06vU1sGvdpBwDmE : Steely Dan
# 1peoXq0RPx7czVoFjloeDQ : MAVI
# 3A5tHz1SfngyOZM2gItYKu : Earl Sweatshirt
# 3BLx7avD36sNpMNA1nZ7Dj : Take Van
# 3ZMur3elMyOs248ah86NRk : Mach-Hommy
# 53xeKWbSRuGgTxViJTAZKC : Sideshow
# 78rUTD7y6Cy67W1RVzYs7t : PinkPantheress
# 7r8EHfxHZHU16sUV3BEH1t : Macabre Plaza
# 4WjLhyf6zlQ4R9v7uVDN2E : bbrainz
# 5y8tKLUfMvliMe8IKamR32 : d4vd
# 7n3JQjlRlrGp9JOcLzSPlR : Groovy Kaiju
# 08Ld63UgKrJ0nZnCkzHtzc : Project Pat
# 67qogtRNI0GjUr8PlaG6Zh : Zeds Dead
# 1U0sIzpRtDkvu1hXXzxh60 : Kelela
# 1grN0519h2zYqpRtYbDZAl : Larry June
# 1xqPIuafmMmiYi3S5G7RSm : Foolie $urfin
# 2imvddeWiv58tUPKh8q3kO : lil hero
# 3TVXtAsR1Inumwj472S9r4 : Drake
# 50co4Is1HCEo8bhOyUWKpn : Young Thug
# 6hQx28f86hT8QSpaKammmZ : architecture in tokyo
# 4eYVVrnphe4blxWuzahYQE : 猫 シ Corp.
# 0ABk515kENDyATUdpCKVfW : Westside Gunn
# 0tMnuEXTeJeHbslcV8OybJ : Drugdealer
# 10QsMlOuybvc9TD7emF1rI : Elijah Bank$y
# 2OaHYHb2XcFPvqL3VsyPzU : Rico Nasty
# 0va8U409dr4gA1zQ2gSnD5 : 18 Carat Affair
# 2N2l2BR0KlnQrFnOn7ntEN : lojii
# 2YZyLoL8N0Wb9xBt1NhZWg : Kendrick Lamar
# 5qm3bAgsYq5aBOymqkM4gG : Makoto Matsushita
# 5yPzzu25VzEk8qrGTLIrE1 : Young Nudy
# 6aaMZ3fcfLv4tEbmY7bjRM : Isaiah Rashad
# 7pDkjftAxiFHomWsPNkapS : DJ Muggs
# Analyzing your top 50 songs...
# Getting your top 50 most listened to songs...
# Extracting data from your songs...
# Writing to file...
# Complete.
# Searching for more artists...
# Performing base scrape...
# Artist scrape complete.
# ['lil hero', 'mysticolu', 'kittygonebaddest', 'staysie atoms', 'Take Van', 'CLIP', 'YUNGCYBERPRINCESS', 'BÉBE YANA', 'Precious', 'lostrushi', 'Alé Araya', 'heymusou', 'SUMIN', 'Alex Sloane', 'keltiey', 'That Kid', 'Marluxiam', 'kaystrueno', 'Braxton Knight', 'Tommy february6', 'kezia', 'King Krule', 'TV Girl', 'Beach Fossils', 'Current Joys', 'Cults', 'salvia palth', 'Alex G', 'Eyedress', 'Loving', 'Vacations', 'Duster', 'Strawberry Guy', 'Good Morning', 'Mild High Club', 'Faye Webster', 'Surf Curse', 'The Growlers', 'Men I Trust', "Her's", 'Crumb', 'Duwap Kaine', 'BoofPaxkMooky', 'Izaya Tiji', 'Tony Shhnow', 'Texako', 'Cashcache!', 'Glokk40Spaz', 'Babyxsosa', 'Hardrock', 'RealYungPhil', 'TisaKorean', 'iayze', 'Rick Owens', 'che', 'Summrs International', 'Lil Candy Paint', 'vjac0b', 'ICYTWAT', 'Dom Corleo', 'Hook', 'architecture in tokyo', 'FrankJavCee', 'Whitewoods', 'Hello Meteor', 'A.L.I.S.O.N', 'Emil Rottmayer', 'Blank Banshee', 'admo', 'Dan Mason ダン·メイソン', 'Yuni Wa', 'George Clanton', 'NxxxxxS', '２８１４', 'Skylar Spence', 'ESPRIT 空想', 'Lucy In Disguise', 'VAPERROR', 'Zane Alexander', 'luxury elite', 'Macross 82-99', 'Marcellus Juvann', 'Angelo Mota', 'YTK', 'MFnMelo', 'Isaac Zale', 'Kyle Bent', 'SwaVay', 'Dot Demo', 'WELL$', 'Zaia', 'Chuuwee', 'Alex Wiley', 'Tedy Andreas', 'Nyck Caution', 'AKTHESAVIOR', 'GRIP', 'YGTUT', 'Trent the HOOLiGAN', 'Mark Battles', 'IshDARR', 'Maitro', 'Cosmic Cycler', 'Cocainejesus', 'King Quartz', 'CYBEREALITYライフ', '회사AUTO', 'Nmesh', 'Infinity Frequencies', 'Incorporeal Visions Deluxe', 't e l e p a t h テレパシー能力者', 'Jordan Ward', 'Domo Genesis', 'Navy Blue', 'Kenny Beats', 'Joyce Wrice', 'Sam Gellaitry', 'Zack Fox', 'NxWorries', 'IDK', 'Duckwrth', 'bLAck pARty', 'KAYTRANADA', 'Kenny Mason', 'Planet Giza', 'Saba', 'MIKE DEAN', 'MIKE', 'GoldLink', 'Elujay', 'Hit-Boy', 'Esseks', 'Kompany', 'Champagne Drip', 'Dubloadz', 'Tisoki', 'TYNAN', 'SVDDEN DEATH', 'Dirt Monkey', 'Space Jesus', 'Space Laces', 'smith.', 'Moody Good', 'Barely Alive', 'Bear Grillz', 'Midnight Tyrannosaurus', 'Eliminate', 'Ray Volpe', 'ATLiens', '12th Planet', 'Dion Timmer', 'piri & tommy', 'Nia Archives', 'p-rallel', 'Sammy Virji', 'Watch the Ride', 'Conducta', 'salute', 'yunè pinku', 'Eliza Rose', 'CLIPZ', 'SHY FX', 'Three Stripes', 'Finn Foxell', 'MPH', 'YAZ', 'goddard.', "Barry Can't Swim", 'Pola & Bryson', '1600j', 'Vonte*', 'Slime Dollaz', '10kdunkin', 'GOONIE', 'Lil $horty', 'Devstacks', 'Izaya Tiji Archive', 'Summrs Vault', 'SiyahXO!', 'Diego Money', 'Smokingskul', 'Jerm', 'Niontay', 'SURF GANG', 'gum.mp3', 'Na-Kel Smith', 'POLO PERKS <3 <3 <3', 'Bear1Boss', 'Sideshow', 'Pretty V', 'Harto Falión', 'Louke Man', 'Dazegxd', 'Zelooperz', 'Bootychaaain', 'WiFiGawd', 'Popstar Benny', 'RXK NEPHEW', 'RXKNephew', 'Remlarr', 'AnTgry', 'Flammy', 'Hatena', 'CHANCE デラソウル', 'Uni Deluxe', 'Skule Toyama', 'Luanmer', 'BarbWalters', 'Cape Coral', 'Sui Uzi', 'Sparkly Night', 'Rhodes Rodosu', 'ED.', 'Iden Kai', 'Mélonade', 'Strawberry Station', 'ev.exi', 'Proux', 'ConsciousThoughts', 'ODIE', 'Kyle Dion', 'Emotional Oranges', 'Leven Kali', 'Aeris Roves', 'Dreamer Boy', 'Arin Ray', 'Choker', 'Sylo', 'Col3trane', 'UMI', 'Orion Sun', 'Samm Henshaw', 'ROLE MODEL', 'Mac Ayres', 'Chiiild', 'Lou Val', 'Bennett Coast', 'LOONY', 'Caye', 'Ovrkast.', 'AKAI SOLO', 'Maxo', 'Medhane', 'demahjiae', 'Jadasea', 'lojii', 'dj blackpower', 'Chris Crack', 'Pink Siifu', 'Theravada', 'B. Cool-Aid', 'Fly Anakin', 'Chuck Strangers', 'Kahlil Blu', 'YUNGMORPHEUS', 'ZekeUltra', 'ぬいぐるみクレヨン Lush Crayon', 'Passing Currents', 'Cortex', 'bliss3three', 'Luna Li', 'Puzzle', 'Enjoy', 'datfootdive', 'Paulie Leparik', 'Downhill2k01', 'Alberto Baldan Bembo', 'Vertigoaway', '流線形', 'Salami Rose Joe Louis', 'Adolf Nomura', 'Slater', 'strxwberrymilk', 'Blue Smiley', 'Ginger Root', 'MIMIDEATH', 'Tommy Richman', 'Wakai', 'Diz', 'MARCO PLUS', 'Ahmad Anonimis', 'Perry Maysun', 'femdot.', 'KIDZ', 'jev.', 'Yung Senju', 'Muchi', 'Malik Elijah', 'Marigold', 'Trapo', 'KWAMZAY', 'Young Wabo', 'Swa ...
# Scraping tracks from collected Artists...
# Gathering songs from id: 2imvddeWiv58tUPKh8q3kO
# Track id added: 7jYd6GwT72RhhKMTZ64Z1H
# Track id added: 6eaVsqo6fYuHnDr9cSNYmd
# Track id added: 355eZ7ojdzc0ZHc7LeiwE8
# Track id added: 4wx3jt0cWGrHK5EK3z62RW
# Track id added: 3NBnCQuFNoQu4rwvYXG6fg
# Track id added: 2CmUklrFzrlGjNqsdpudvo
# Track id added: 4fuQgiENvxGezAzzRW1K6v
# Track id added: 3HXw7XwOtmHSTbUXOqvtwA
# Track id added: 1Eytlq1Q4PkDT8cK8apihP
# Track id added: 685EG7Fe20flh7vTUAKRNj
# Track id added: 5lzFeM8bqWqEBtOItCrZVw
# Track id added: 7b9QFSD7z0dVM3aMbBD94C
# Track id added: 3vmNRz72xAeToBoHEUfKc3
# Track id added: 1GKSGRA08GJzWkhRQ3S2r0
# Track id added: 0yoDfDf23ty9N8tNSx3H9v
# Track id added: 5umFwFTvzmaBk1AqoW6q8H
# Track id added: 5vGzyLVRfWTRsW3Jc4k2Qz
# Track id added: 4qgdZqAlc8TMpGXmYPtiTX
# Track id added: 3qtBCo1WpIKAXFK5bKcGe8
# Track id added: 2d6mH3qUECC4FBRx21lvut
# Track id added: 4IdeMg2HCC3SdCjL7YPXnl
# Track id added: 6MiwFe3vJHx0PTopm4ArwJ
# Track id added: 0g7JaOzAwtzYDC8uzxrZs2
# Track id added: 7acyVED4sGY2dsuMNsJo3X
# Track id added: 0Retxsty0yuRrGi821k4Wx
# Track id added: 6nsz9zgHLfcBNOXtHBX8og
# Track id added: 0HdSlLF6Tc5czuRBBv96BK
# Track id added: 4AQaMxCTftGqMV4CTR3OdW
# Track id added: 0soSTCDdo3EGNrtSxNKVvs
# Track id added: 4WSMsMG3oM9GFP8lIN27gN
# Track id added: 3RQQc3RyoxXV4S3jueXBuR
# Track id added: 5DisDxRVyC4pnpf3X5hUTL
# Track id added: 14Zk6i5hJPEfzgFM0dQg1e
# Track id added: 4rFRo4IKQCkvH0P6iRpIe1
# Track id added: 2ELUWcviqARRGwyfbISxw1
# Track id added: 644YGv8URMidq6HM1wgFDX
# Track id added: 43QnD0Vlr8tFfTR68SCTfz
# Track id added: 0Uk6zI0wLJ63drqABWW2fJ
# Track id added: 5dQQLmyQZOXtJxX0lsImNZ
# Track id added: 6Fa2UQhSHxAbCNy6h00hZr
# Track id added: 1PYYHspEqV6GCWpu0J9ujm
# Track id added: 7qniMDCab1uBw4TA4ZGSfj
# Gathering songs from id: 7JTGz5LCS7T8U1kZs0DIVZ
# Track id added: 5dNbassbXKlPPNyACanea0
# Gathering songs from id: 6JTPZjTtAwqn7WNoZqngW5
# Track id added: 4pSsuzumUi1Kw5RdyvPiVn
# Track id added: 1PilWYmaZ1l9GA9Ch8CHno
# Track id added: 5r9Qcie87IUCMiSSrL64Zk
# Track id added: 14wo8hdDC3ZLeZX41ujZpR
# Track id added: 4rjVxICWEgv4tEQF1FZ4Ol
# Track id added: 5PG3cwKPGqzn6I9UXzyOyB
# Track id added: 0Km52EQt8uWUA7Z4OMz5Ea
# Track id added: 6HkuQkaxR5QKc7TrUM4gy6
# Track id added: 5yhnmXezdoCUBxeBxjzvL6
# Track id added: 50pjdjvaO6QSNPuvQ4rCrQ
# Track id added: 4KaFzWm0M1ABSRghqArlqx
# Track id added: 2nvYkq618H58EAP1bcswFR
# Track id added: 2ykqS8yAM0bD0zeiM035pm
# Track id added: 7M1SKvbDonOqVcNR26J0Lz
# Track id added: 1Og4VLfASCkNWDkzFYrulQ
# Track id added: 1DkZkGM07uRfLaILEvAtrG
# Track id added: 2MZKMntigNwKesFsdfVxF9
# Track id added: 2xexm5VKbFilWHjHzTRGWD
# Track id added: 6uXtNB0lOlB2oRyu6D6WSu
# Track id added: 2xc7IA1kH8rV9boxjshgY9
# Track id added: 3AbjyJS0yTx9JrYWUoJJ7d
# Track id added: 1CJGiGttIv7Ck5bYduxSZn
# Gathering songs from id: 6q6WHn4XUvFiS5sx3dFHHd
# Track id added: 0dNAowIWOgA3xdC3K8dvJu
# Track id added: 1jnMIg3zxhxXj9omhEpycW
# Track id added: 2yFcOP0Z5DlT3qhJ4abXa7
# Track id added: 1GVmfFmmNmByaF6I6LDl3B
# Track id added: 3Ph9XByOeJT71mflpVIKXw
# Track id added: 33t74h3k13rgCi9Nhtplma
# Track id added: 4xcxfC263RPzE4xKGH7Lle
# Track id added: 2ueo7YKiemHHF4dM3MIapM
# Track id added: 1xUqxllh9KmNzL6uqyOIDW
# Track id added: 4cEzceoklKOnD9LOC2cnb5
# Track id added: 6F0M1gmftUmaeUpPNI3zbl
# Track id added: 6DsEFVRraESNoXxYhRv0pS
# Track id added: 2hJmMj6nH3zmEiAoSEEwtJ
# Track id added: 1tWW3bCx9nxUEkMYHafZwK
# Track id added: 3godIEbOwcUikPAcbOeEk1
# Track id added: 4RYcN3G71xtFR2XnUqKjWR
# Track id added: 5HE1hrdR1ryp3vRrSksDXa
# Track id added: 4l96cCXFdMdWfVTLguro59
# Track id added: 5J21Cy3E5M6VGbriYTOB08
# Track id added: 4VqkXn5RFoQR4EBFIioXrx
# Track id added: 1mBGP27vSqk0JysAcMBT06
# Track id added: 2cnyJP4dWnaztPFES613Ux
# Track id added: 1UNK5pBdkRlpLa1KteLkwH
# Track id added: 16j0u9wsUeuSuKB6jtD8VZ
# Track id added: 7EgcwBNvzB6fQjbQ22Z9Ir
# Track id added: 7tTr8G5PfEC80K157O90yl
# Track id added: 68oZxozVfPZYCjHlfpJGGR
# Track id added: 2norHmtZzvEqQ5zIHdcfR0
# Track id added: 034YMh0D5nDU1zrwL0JfKp
# Track id added: 6c0rqHPTdQ5I3ensXMAZ7D
# Track id added: 7JAKNDcJxLDynzMmZ63X4i
# Track id added: 0EuVVIOZxcvEspmp6rcigw
# Track id added: 3mSg4WEr1HVaJNVKTYWdoi
# Track id added: 0T8Lp23QA71NRZ0GSH8mmd
# Track id added: 2metD1ZFx20lhoPNDjU3l7
# Track id added: 1fZJmR12F1ojA9aSrk8kQ5
# Track id added: 5T6syj7InMbSEWkr84ZMay
# Track id added: 3VvBH0gw0hwLrFuop89LCF
# Track id added: 7aFTCoSgeatE9NFg24IpU7
# Gathering songs from id: 3BLx7avD36sNpMNA1nZ7Dj
# Track id added: 5cQeaLRQODRZqnfOxbPSPY
# Track id added: 5a5q1sFcpMoPRk5fRGWq2W
# Track id added: 4q2OpwP2T05E3diEio0qNT
# Track id added: 6nX8TIy6eS7WIrMNuvgf2o
# Track id added: 0C0c9KenrDHeCDw2XPJgqb
# Track id added: 1NbnMc1v8d2mSJBpsGRpfg
# Track id added: 7fhg7ofLpD5Maiy9Iy2PJC
# Track id added: 6grlBYKqpLsnZcoy9oa6tw
# Track id added: 1JPssH9Ue73hHmEWJEEhuy
# Track id added: 4P9tF1AaSpkaKk3Loq3Nvq
# Track id added: 1cQDVC4lF9BRLgFAS2pN2e
# Track id added: 1skhJo6DgdqoCXF5R77KY8
# Track id added: 0gx28VeY5jvrl8Rm1w6UaZ
# Track id added: 5mEc78BjIID1vc94cqy8TO
# Track id added: 4DJhNVWhxFCCgLft45zp80
# Track id added: 1xJLcGv28TmXZsjz4eFdCM
# Track id added: 0tMvcmXxGahfGzzp69RWCR
# Track id added: 0WCMwhETNm25ggaE8Ue9HZ
# Track id added: 3fe0sBQNrGVyDr0jF5B4Cg
# Track id added: 6i2T7W4sbzn655MIjswcZV
# Track id added: 4W2c3LX6S00WBhqUpdTy1A
# Track id added: 4p9ROZgApJpuFRKl2Ffhbu
# Track id added: 3VlZSJOZpw5WbLbctHD43T
# Track id added: 1SmlpzSJLpt3puZ9Zv3zTo
# Track id added: 6QXoQhDw7HyTQvbdtIJBh3
# Track id added: 3f1U8sOvs486Ztmh8AkH9K
# Track id added: 5ui1oEZQZMN22ZxRLCZxDp
# Track id added: 7C3TDlzOFprA01H0KG1EmJ
# Track id added: 7KwJkLQDQXV8lZdtWI5fSs
# Track id added: 4AooTesmImiTzl365Wtc4U
# Track id added: 0TvjxzsA8ChevNjIvAZpFI
# Track id added: 13rLO5IWB08MQEkV4MtNOZ
# Track id added: 3U9a8AbWMEPWrBMAmdny8x
# Track id added: 3egFe1SyPCWemcmS5iXMMQ
# Track id added: 0KZ2uXoJ14WMLKAc9iqS01
# Track id added: 5HGGgydFSuStbLFwN6w4yT
# Track id added: 06yoIDsDBTcntxXoCVGSm1
# Track id added: 0TFrnIhvD29kAWE91npCEB
# Track id added: 63taz5LtTDqdSWx0q650Lc
# Track id added: 4EEuuFvtU8f1SjDukYcg75
# Track id added: 0hWmTxFdYcB2a2iBXKEoNy
# Track id added: 2hYjoqwUAogcQMZuVLiDUq
# Track id added: 5H0FkEAzNFOgAeP3UrsxHg
# Track id added: 1GoHMrUouzIum3zx68qBHn
# Track id added: 2YmQgmeLOcx6bFsVyjvaQV
# Track id added: 5Sw54e8LRLy8uZ319h0b1z
# Track id added: 7bWMyLaKwQQoeli3yXgCys
# Track id added: 2TFK1hTWvMX3Qd3edmb3XP
# Track id added: 4c4ogKpNuBTBcRrdjY9K9V
# Track id added: 564qh0BKaAve4kW4oXSzlA
# Track id added: 1KxN7YAt9s6Ahyx9r0oJk1
# Gathering songs from id: 3gkLLAZaxTaJhHnUaxQzCl
# Track id added: 4RN4a0h7o3Cxv2mJSHxKJ2
# Track id added: 4xnQeMktACQalLtoHL0CEC
# Track id added: 13kTPFN0KVckuUuLyHsKcn
# Track id added: 62cboyofQAVrwGkZiMWPtv
# Track id added: 2WUFCVZVYVgFZ7PiZBdIpi
# Track id added: 3VTXOxSFp4bkIEoR9ydsLG
# Track id added: 53uCvsosj6xG2QGTMkmypM
# Track id added: 08KYuRtmVJW92gtGFx7Tew
# Track id added: 0mw5WL8vDK1hJT0vbUM07w
# Track id added: 0OF1hvESy982SzleW712MM
# Track id added: 2eLkaSkb610y89qo3CreHo
# Track id added: 6W9Xu1OZTrEjE2YtxTFxMR
# Track id added: 5ewEnojDl48qKyvdXJHcVq
# Track id added: 4QtlxfLkHsjGdSxEwJapHW
# Track id added: 6zWcEyrSS9gFtWaixDgp0q
# Track id added: 66SttgdaylqSJ0QKxAQx5L
# Track id added: 6Wj6uflU7GqgctkBghxQ3K
# Track id added: 5Hgt6L5q65GHX05Xbi2V0q
# Track id added: 4gYZkc2AUXlx0F8xuqAwFM
# Track id added: 2raP4NiUEmFyEqlz0jBQp5
# Track id added: 17m1v55LpA8YHXm7ySmeJv
# Track id added: 68SoK6pKJoA50a8JQVaMde
# Track id added: 3S3vbcccF7wC57LNyk6Iwy
# Track id added: 0EbW2Ez1yv4uThiId0fLy4
# Track id added: 4XAB4xDDzzHmbRY7FheQ30
# Track id added: 32hKezEtd2cxonc15nw3B6
# Track id added: 6oeRoFUOJ6CAD4GTDJkdru
# Track id added: 62lr6b13u6BuUPfMny6Z9z
# Track id added: 3gXDjCIfkFWY7v2p73TTq6
# Track id added: 1DiN04DBMm2Bj6rKgLfuDT
# Track id added: 0Ja2Yfv35VOl6em28s62bi
# Track id added: 5RGscFJfeqm6iXwEyao6Nd
# Track id added: 7CUzlDysypivdFKl6QgiGo
# Track id added: 4sINq5juAUOZyLM8L85JzF
# Track id added: 1kQbwHWgUJcrL8qV9ZVLzP
# Track id added: 4qh5K6h8kcrKzyYlQMAG1y
# Track id added: 48M2kP5KdV0jp14Xzu8lhr
# Track id added: 5qIihSA7DuI72Ic6d68AMJ
# Track id added: 5ggxup1KzA8EcEFuWp3HsU
# Track id added: 6BNoAl0pKLOOmVHs2WW9JF
# Track id added: 19Sic56cGSJU9lXpwFCFHa
# Track id added: 6abEx5tQlcVQc7AZd02NYB
# Track id added: 5OLoqqsLQhRrDazY90t9zD
# Track id added: 3ZPGO7K4bcxcUDkSrLGbuz
# Track id added: 0Nkreykc1ebw27uq0eNr8i
# Track id added: 5S3w6kvQgOmaKvzdsQBgD5
# Track id added: 2lirMZmScsD7dyGhoAUsiN
# Track id added: 1pb8ULvtoqfo2vUFYi09rg
# Track id added: 1v0wJJAuiw4W2kHqVPXFy4
# Track id added: 5wC6nde51jWRkVSJ9EzLXT
# Track id added: 4Uq9xSPbomZi9H60UUVORi
# Track id added: 55yzrqEPjscQhXQLmkFBQy
# Track id added: 0zk7Egwo56OXBsPgBKZidK
# Track id added: 0uddpXGf3JpjRRGgJ1mJzk
# Track id added: 5r9gQIQlWTs1z8EhPfTDf3
# Track id added: 2GbYPi4UPjEvLYQWT4nLrF
# Track id added: 1YLS1sfQCGLn9UpL9lYfgt
# Track id added: 645WQQvpCLQLSjC5sRx0FU
# Track id added: 1Rc07iAuWj7Vc3hALF4fsJ
# Track id added: 7fArjoUK99qF1lGUvnazGU
# Gathering songs from id: 1s8CGPUhqhhH9UkNoK9TGZ
# Track id added: 6ho5I49ybvEwuMmmUGDGLv
# Track id added: 5A6D0MCApHBiqGYUZUBNLT
# Track id added: 6kfTKkzpQzXJO51DYMyfIh
# Track id added: 7E7dVqCdgZGiDKG2uHRio1
# Track id added: 3GPsg4GnrP4Zv55ZT91sEo
# Gathering songs from id: 6ozuxhSx8Ci0o8tPpgrCT2
# Track id added: 3RscSDB2uUc7cqjZZSChkg
# Track id added: 2rLUKXLJN0iGm2F3zBxq3d
# Track id added: 39Z0oMsUG8sU6NNLOXLL6k
# Track id added: 3YdyWBLWAx2zu5mMN33Ujk
# Track id added: 6Qxyowsn90zcO5guo9vwl1
# Track id added: 3By3oqk1N39x5ccIwKlks9
# Track id added: 2PhUsk5qimnIOOEoQ80ErP
# Track id added: 1xiGZZhd8HQQpJcmnqqrEl
# Track id added: 5VtepaEMpap2EdFnnof2fd
# Track id added: 5wyau6dzDldoBsya9pwQ8v
# Track id added: 2Ypzg19HAN5XrUb4aK9ynI
# Track id added: 4g2T8DCjnV47KpVLjvaJIS
# Track id added: 20pgDPS54Fnez3IQhiOWIl
# Track id added: 40DhYNOtlg5vro3eXfp54V
# Track id added: 765hP0WPcDqny3UX69Qt6Y
# Track id added: 326ZUDFRt7cVQ6FeitYGXQ
# Track id added: 2w6wYoxmmBnCOq7ezrNy9n
# Track id added: 7GcEnwzmN5Q5kuLimGAjAk
# Track id added: 1iopNk5KVEH6xHEgMjfO16
# Track id added: 7tbGH0ZPBIwoEukMhIgR2G
# Track id added: 2guFO9dGgn6A2U2B91Lgc1
# Track id added: 7f8cJjvsn1dPUamKFdLnSB
# Track id added: 0rXZfC0pn4z9ULv0wpIJd8
# Track id added: 5SIGQyJQqctDaC2asm8jdK
# Track id added: 4VSedQXOJyyNDR50mAKiWb
# Track id added: 3pC5uW2ccFbDIkxSM264im
# Track id added: 4bnMjvwpv1eVUn0xz8sItQ
# Track id added: 4X9MXfCcpky31EeMSiEvd6
# Track id added: 4psQvhuh4SWdSpWG3MBPDJ
# Track id added: 7mZliakmeP3a2MIUO5E95B
# Track id added: 1AvFLos2LmUJ6yD8MZkWMp
# Track id added: 2IIRMVR0pYXzPHOBLkBjpp
# Track id added: 7h32tZFHxN8FJe4Zklacpx
# Track id added: 35QHX5MI7JpB0xwX4HZ1Df
# Track id added: 1YnewALtpmHPZg86MgB1C0
# Track id added: 0OlADwDq7CuXr4vBRSe9Ii
# Track id added: 0eqKHE27ea31pDZEyim6oj
# Track id added: 3Qu9FWXMpbRLqLbTDItsVT
# Track id added: 78CZ6hMguuuNRIkLcJRXiX
# Track id added: 2DBrLFkUqtCGmjgTFFM0fE
# Track id added: 1Vi2s9nZLEQOae9v1i29Q0
# Track id added: 1ghQ6Z2ns350hJ6yDKkXBO
# Track id added: 1HhrR7Hm5TnMTaiCfdYx4N
# Track id added: 4Ygef6JVrD0qhA9427G4U1
# Track id added: 5PlyvWABmTfNjRT2wr7L2B
# Track id added: 1fjmOwYpFYoCma7tJCaTDu
# Track id added: 0HcEPwTLEor111rS7jfPec
# Track id added: 4Chpo5S5pl6PIicXdzIiHh
# Track id added: 7MSjY6WPnqmZoGrxv31eX1
# Track id added: 29LbX1qd5r2DgAw7t337A1
# Track id added: 56niYGfx5qfD4h1Yu7EKoy
# Track id added: 3Ounw2FcSH14X7Se2M5nus
# Track id added: 6Y70rkqfWntvUdOqP6BWai
# Track id added: 20trMmhtLpoZmny1nI1HI4
# Track id added: 2TB15WOlRw39MxaZ8UOGGR
# Track id added: 00GGkL9ZrMk3nxE6OzxBO5
# Track id added: 5GJfj9yDZOEtmdtxG6iuyL
# Track id added: 3TLPQBi6uCM9uITnLfOAzU
# Track id added: 2g2YHaIKwKF8CYfhBJ8reB
# Track id added: 4yrIvh021QjBpOJuBMn0DQ
# Track id added: 0GCj9zPlZ4nB6UjUdK1QTq
# Track id added: 3RBw6UroLeBXZ4Ex2pjDdg
# Track id added: 5cqDtjuiGXwSHzzyX1tJNc
# Track id added: 14r22IjGmu1n9Cczxe3TLO
# Track id added: 0IvoFSGva9OKLCQwta8MJP
# Track id added: 2TxBZ6kYX6rsTchKcpT29K
# Gathering songs from id: 4bVL2bLOv1PLQXHDWXNMPE
# Track id added: 10ZfXrBNEK8a6C6yvm3B9O
# Track id added: 5H99b55f93cGd7108oekqk
# Track id added: 51cbJiCYM7iHcwjcmSyG1v
# Track id added: 58ALnxB6eZUu5B9anN1qR9
# Track id added: 6NuLr1D87PTxr35ZmzaLDu
# Track id added: 7d60eRxmlk5tWiAxqQWtzS
# Track id added: 1EeXIbuIkcyAyeoUT3JRO6
# Track id added: 2xEUrItJj213bm7WCniQWb
# Track id added: 5fPHVBIsUN76EC4nDl8FjD
# Track id added: 0VrI3ZjG79JFvdTdzbiBlZ
# Track id added: 3Sh0dIwJnYrWxi3BoZaSx5
# Track id added: 1Z4IW3HtO4Q31eatLbYNzp
# Track id added: 6mp99sZNwk2VY0omrwjOUe
# Track id added: 1iABkMZGhbvOzqQFbsCRHa
# Track id added: 0roPSSqfiQDLmQIkqdyx4k
# Track id added: 7wbhxJ7v6hKazR7WL6czQQ
# Track id added: 6KQ4xmMQa4MClbj0CcpIMm
# Track id added: 5r6fENlTDs5NjSgmbBiHW7
# Track id added: 4JXLxH8zPQX0JntLWRUR0c
# Track id added: 4DYSddT7HFZtFaoAnY5D34
# Track id added: 1pyWemHBYrgs7D2wTvLRDk
# Track id added: 0a9Ht7HQXy1Rk4Gudtl0qv
# Track id added: 4p3AtXEYX93pPgIk0i4Sop
# Track id added: 1cUfu9sfVIGskhIOyMd1Qj
# Track id added: 0ayMbitcsoK3YleIaIHw6Q
# Gathering songs from id: 5Q2SPodgRF5DgI5Vs8y0Ve
# Track id added: 10XmIlxDrqMkQZsk8wp7a7
# Track id added: 7GyboGoqMl5JnieBy1uBPR
# Track id added: 3E2hv0xzspUirjy3NBBGZ3
# Track id added: 49l7oO81flNEH3425Vtnnp
# Track id added: 2ohcmWDRv5L4jxEYHhghAp
# Track id added: 1uwiTdqmW7fwgsNNcSoqxN
# Track id added: 3LdAw2mOs4nbl1FgJ1y58y
# Track id added: 5tvZrQ90RTtcIWtPbJ9YfM
# Track id added: 43xCBCSikuYLaf3lc4Sbxt
# Track id added: 2lvaJcZ8zXSKoX4Qi9yOX3
# Track id added: 2u40Y8hC6ONfeDiut3NUUj
# Track id added: 1mNArVEfBWUJyByG2rvd46
# Track id added: 0hPkx72NLW5rvSAppoicH1
# Track id added: 1wBAemb9iKMXVzgw5HWK3I
# Track id added: 2VMbD3KL0uGnXZLokvZQ9B
# Track id added: 2YlXMGTIggK3ROPpwn0uop
# Track id added: 45HfGcpSOdONzhojEwRmv8
# Track id added: 2vj18lzxjh4GyY8eVFiXAV
# Track id added: 7BeWNdJIAc50JIEDpbaObW
# Track id added: 0iaWAjuJz5f5SfRsKMUMlc
# Track id added: 2Sy9I341oa5h0NE5U9QEQm
# Track id added: 557hXetU8MYDAMoclI9V5k
# Track id added: 2PWkI4oeiF5Zdzs4uvfi94
# Track id added: 4agaZwSQZq5OFau4LHdYVV
# Track id added: 1fle9hw3sX1vqbkxHUAvPH
# Track id added: 3fVo8Zs8E8t145V48jfyQZ
# Track id added: 74kIeM49uIA7G5dH6paxUX
# Track id added: 4cNIG9RPciHjndac0qNdKI
# Track id added: 5iMb4ayRUXy9H1BXYtZixo
# Track id added: 2QHwJhP5Es2KDngYidrAlA
# Track id added: 5ZNsj0iqDzlxiZZo6ad1Ic
# Track id added: 05Zc3HxoXzLle5feEJ2j5A
# Track id added: 5htFUClTjej2SgM6gggoCX
# Track id added: 66dREevdfFPQJcKwErqEQv
# Track id added: 7tNLeO6ByT56i1QUXKvyAl
# Track id added: 6cgJWJ4gcwePZsB3wdtcOr
# Track id added: 67kW5vMpoPiDVefgweAvjK
# Track id added: 2bHXVnRzE0d8DifNsaUcbI
# Track id added: 2YQyl1exc3T5Q3fJ9q358C
# Track id added: 2Q4iwc9Q8lC5VQzdnYVw03
# Track id added: 0WpSrQvNE77V0MNPimDjpb
# Track id added: 7qzbZo9WdJC4lvpDSGzmql
# Track id added: 3MPToqp5OnyqZ0umzd7O3y
# Track id added: 5zGU2KyHT1SOU3hekj4Yda
# Track id added: 3s8bPwWBNczcGEj9QHVb1j
# Track id added: 3sGgq1Lqig56CQagEPz66T
# Gathering songs from id: 2kcVXlSyLmHdET22JmJ4jK
# Track id added: 7Hp9zYaQibVL7pycwFWkOT
# Track id added: 0iwAy0Fazm32XajQTM3TVK
# Track id added: 1q3IPJtWFRfUNaRGEGGVQa
# Track id added: 6e1b4sFgLsOSQSqfCLCM5I
# Track id added: 6XbAxYhahXPykiTGFh9Ifb
# Track id added: 4lmGsSnTDvkSer7DkaK7HP
# Track id added: 3eBd1Vds3EAJz3RFdZwz7m
# Track id added: 16ORoye6qqKr2hORkxDRsD
# Track id added: 5TyqlrHJpJvdwzy89cFhza
# Track id added: 3d9hnkwJ7GFfXxRg0bfRwo
# Track id added: 7rMZLoNv83fqb5vY4eunmx
# Track id added: 6c75l5YqH6zvcfz5wu0Ra7
# Track id added: 3dd00zN0zP5dpbBPZqwfIp
# Track id added: 4TlIIHzB3LgHmrPofscKtv
# Track id added: 5755xYOhP3gUv42Tb3FMg3
# Track id added: 6SCZhsx5jO9wW0z9Lx6eP9
# Track id added: 3s4QIE9CMkTRCufw1q0evm
# Track id added: 61ob8L0WuwytlW2NjYDBtL
# Track id added: 6PbJyt2g9NSbs4Fu4FV9b6
# Track id added: 3wFyrCDvYgk1pJcPt3fZJY
# Track id added: 7qFWKaFLMzkZHON9BA6FhL
# Track id added: 6wLJq5SdNgt9KQVEYIbgnr
# Track id added: 6h5NBmu9iYkJkFtDHv46HE
# Track id added: 5T8NpyPQdTIk7RNusJTBXl
# Track id added: 2mdjWao9oQFmVfSS1PLXyb
# Track id added: 5ILrf4vi1nju3fBStkjjau
# Track id added: 4ph41amWGPQoL8mbr9hMVm
# Track id added: 7EQpWKZul9JJaONyfKVsG2
# Track id added: 5qNZawHPaU1pipF87uwhRn
# Track id added: 7APTkrzGUZk0xyulj0PCLh
# Track id added: 4Bge17w2lJlxR8wGbkgEqU
# Track id added: 1YWNWcRpChHUK2KbQfpfjm
# Track id added: 1uYcovfL03bUhdLdyZ1Ght
# Track id added: 3dQEf5ANakTKxJiDXIDUus
# Track id added: 4mURAJoY9fK7A09A1bRHXx
# Track id added: 0YwcnEt6xJxXQyUbGfw8VP
# Track id added: 4Ok7bCnQ80eRz1ioQqOzcB
# Track id added: 6rnUf3iamSZqhNmEAS962n
# Track id added: 7JZrhgd3l8vMcYOqy8Z2CT
# Gathering songs from id: 7sHAFt0AI2YTEFsYFnDJ1n
# Track id added: 7CjFWewDXNj7R0e9JJWmrv
# Track id added: 2P3lUAfX7WedIKbcCp0QMX
# Track id added: 1CR1cemTcLbzO6C6NBRsdN
# Track id added: 6a0XewK8tv5jsfA9yDP721
# Gathering songs from id: 0K4MGKGmjtdIE0W3GkGmyU
# Track id added: 2qQ0jGYnQHFZQPnsLULsij
# Track id added: 5XCclT9DK6vVcAtR5HMUuL
# Track id added: 39hXM0fPqzUzGCPECajajT
# Track id added: 2bmUFtt07qLcarsVlfE7VZ
# Track id added: 4peRJqGTdLWBu8DtAMaJop
# Track id added: 2ie0f9dJxP1pxteRqCj5I4
# Track id added: 4InJQ9Dukb6RyyF2uFvLyt
# Track id added: 6cVqXzyZD9UtiI6DKFM5TP
# Track id added: 09XBzXfqOeb6xJabBYgVUp
# Track id added: 4TBvT22v1Qmwpk1DzyRYF7
# Track id added: 60roQCMPSE23aQNUVibiBo
# Track id added: 3U4Vc2cEdpxTYSXesUBS9o
# Track id added: 0E8FtO2XTztuSjK01vUiGW
# Track id added: 394GW5YQFpsRMcNahlnID8
# Track id added: 51MjmpKP0qBnWcc57NchSd
# Track id added: 1h5lFBw9v9qV8WfVgZvHY4
# Track id added: 5SHTIXFO2RJa2v0n8hkS8Q
# Track id added: 5v8rNaiQVORMwHuCnBlxDx
# Track id added: 4NeQpG9jqljqxCUMJtvURB
# Track id added: 33QPqMssWzZolwfPSRmkDi
# Track id added: 3GvJNu4n7p4vF42TIgV9Dk
# Track id added: 49nz8M9cYncJ3d7Kah70oR
# Track id added: 6M47OC9gxefeqx65A9nh9y
# Track id added: 0XxujrUMYBoXFl7m1ZNojW
# Track id added: 11BW6WrruL8hgEYxqDVMDy
# Track id added: 1RvZFTibrsjd01EqVvbD4T
# Track id added: 43zn47tyWpVVFCACp8Id7B
# Track id added: 7iC5FfaCVOx5OYskfybFJu
# Track id added: 1UhWcbrAgp4zu8ZjSU9T2m
# Track id added: 6v9h1jc9RxvIHesyXIQN9A
# Track id added: 7vTT6L1Pf6WlDGrJ8iFCyH
# Track id added: 6wb4sNutP2amJaD3OdpY64
# Track id added: 0MLF5da6SiuWndgqvjC8mX
# Track id added: 15pKXLj3nWjeiVgjedy36h
# Track id added: 583rLTKKTkwEuCj0Gri6RP
# Track id added: 5VHcNCSmnKAFFyMaTYtzPc
# Track id added: 5qfPgGDyAQlM48pQM7KO4t
# Track id added: 0JBbyXMy189xs0MEpC422i
# Track id added: 65yq7FjYHIWpK2MkV5LHBG
# Track id added: 2liMcwItUcJgAQEsAIq1Tm
# Track id added: 4WeheYfylgvepzqwV0WiLW
# Track id added: 5NS7PWeAn8wfV0UCYOurQU
# Track id added: 6zRVIoISzIGK1WnbkBRqc7
# Track id added: 5oPDd1wD67qd33UMUbdzPd
# Track id added: 2qLJiG8h6kFV6xDNGaZh1q
# Track id added: 3Rk6ywWGOhw1uonKye1qoW
# Track id added: 2dvX7Chy092P8yDgvcIESa
# Track id added: 3bWf6aZnWGmoXPeVyNyeP3
# Track id added: 0GO7sTQmc8fNx8Vzz5Fs20
# Track id added: 7JLjxZhE5eS3I4cN8n3wn2
# Track id added: 3mfy60rtJuWvuobBO6Zrz2
# Track id added: 24NHRa9P7pZbp8LOE7DAJz
# Track id added: 48ekl3vsB3KHdiPIgsv96x
# Track id added: 4X3pvNxPGhUhBnlqrUFwSA
# Track id added: 4lG3cBBatsPByJkoXXd9ps
# Track id added: 097YwM5ICPaFbVqf0fZUMq
# Track id added: 6ssqzQWVL0viRi1NoHZHRO
# Gathering songs from id: 2oKcZslW7y9ILALBZJhoha
# Track id added: 6usfAcmBp9EhwU24WHB5rM
# Track id added: 4CqiGEzCteguUcpIR1J4Vq
# Track id added: 5HJMk6YC3G3nNkTxak0MRd
# Track id added: 0JE8npto6Umki5igWPczQg
# Track id added: 2teuyvJIhLlnzmKGelAQMb
# Track id added: 2LSvWhLWNZYXIVENr9Anwz
# Track id added: 09RnhOcLqmQHdkRXphffCl
# Track id added: 45Ykf5PogtL4ZUo1azpdee
# Track id added: 4Qn4ovmttmfFfS2LIrEUZw
# Track id added: 4orJLVfupvZcO8u02biRjI
# Track id added: 6Jm7Go6fQpt6TkebxfmnPe
# Track id added: 0s3QSeXPGmZL1D4xPmxONL
# Track id added: 62f6K4BIhmaQEti3Sc6ouK
# Track id added: 166hrAI6YzQFtkA4157uCN
# Track id added: 6tElddBsnnvo3HrRMr1ZyE
# Track id added: 4NWois1DcsXkf985mHXgtG
# Track id added: 6sVkriib5kkcgD9oZ7tTfO
# Track id added: 6TOXbroCRZBFqvjUoObW3f
# Track id added: 5uER2aP4OvNRve1c0BCEta
# Track id added: 42MlJYcWJSx9LrrwVswF9m
# Track id added: 2NHoxYTQdu5TRJa1iSG1sh
# Track id added: 2BJ3JMplmIISrXxsA77JQR
# Track id added: 5U3y98P1vK5EZC9ZB8yI4o
# Track id added: 3g684aXyFCH7mGH00LLMDk
# Track id added: 2f2OQavOesTjuHypoXO5iz
# Track id added: 7xY4r4QzGBQ2JTHroMpctQ
# Track id added: 6laL96AyKy6mO14qULP03C
# Track id added: 53iaGT3X8i5PHxNeGpYf01
# Track id added: 4gxXrA63TFRkxKm7u3kVFI
# Track id added: 4wiJRoQfNJPRGR2T2LWMiD
# Track id added: 2nHs5DBGA6UsKnh8UDDH6I
# Track id added: 6fewQ2ngG27KpXuWs9PWq0
# Track id added: 3X5tABP4pTXUyEiBArYlwB
# Track id added: 5IazsR1gLtzUZoqklD1Pwe
# Track id added: 7Aox3Bkozo4hxgMvgllJ5C
# Track id added: 3nx7NIiM2QRLdf1MDYAYlI
# Gathering songs from id: 6ffRXY5wKedZhPTMa6WGys
# Track id added: 2YhmhcFT5JTlbNHSeKTk3W
# Track id added: 6a2CPvoOR6AYucxHxJhsNK
# Track id added: 6NpUy9lv2cE0Y5gurYUpiz
# Track id added: 6pIujX2ebV70UyOHa0lM0V
# Track id added: 4B0DqbySyGD2dd0aYvZsnW
# Track id added: 6182ACqyZfYCglC3i2iIMQ
# Track id added: 0b4wtiNHlYOT8sGsudYNI9
# Track id added: 27H23TFQ7uYbO4jTy6aGR3
# Track id added: 4s8fQKAfuHR9gMDzoA9ioQ
# Track id added: 7eDh6rWxAg0cjcJRyMoeHl
# Track id added: 1oTuF0biue3CBfcBGQEon4
# Track id added: 2tCl0Rr6mP3Kyoys9xb33h
# Track id added: 4TuPGaqOpHIxPOuWBTmZUf
# Track id added: 7pq2F06MfU4PYDHQHr84Dp
# Track id added: 3D7IsKW2OtjgmEGNcVgKRI
# Track id added: 1bh5u4ILp68UTOC3jS6Mer
# Track id added: 0cVHamxcoQOkb7m8IknJQO
# Track id added: 2sDEcpp7pSyCgGFv1U4awB
# Track id added: 2O0zSVbJ2fb15GbwY5qFx0
# Track id added: 7E9vI8zCSRMgAuuepA6AQF
# Track id added: 2QTb1LZ5O6Pg5PjYepfbSk
# Track id added: 5m3Gj6IljdcLPcPTcLxzRY
# Track id added: 3U9NRVeDZci3wzbnX4deEg
# Track id added: 4fzNYzxCb3E8t5G6C6vZC4
# Track id added: 2qDuYW633Rv3mwLkoeeaq1
# Track id added: 0wwGwZPX3GGATD8n9RIytp
# Track id added: 15pSEcVzyJt04WEjvNnrp8
# Gathering songs from id: 7mUQPmZ6OzwtJEEXDOqyOY
# Track id added: 40DhYNOtlg5vro3eXfp54V
# Track id added: 765hP0WPcDqny3UX69Qt6Y
# Track id added: 326ZUDFRt7cVQ6FeitYGXQ
# Track id added: 2w6wYoxmmBnCOq7ezrNy9n
# Track id added: 7GcEnwzmN5Q5kuLimGAjAk
# Track id added: 1iopNk5KVEH6xHEgMjfO16
# Track id added: 7tbGH0ZPBIwoEukMhIgR2G
# Track id added: 2guFO9dGgn6A2U2B91Lgc1
# Track id added: 7f8cJjvsn1dPUamKFdLnSB
# Track id added: 0rXZfC0pn4z9ULv0wpIJd8
# Track id added: 5SIGQyJQqctDaC2asm8jdK
# Track id added: 4VSedQXOJyyNDR50mAKiWb
# Track id added: 3pC5uW2ccFbDIkxSM264im
# Track id added: 4bnMjvwpv1eVUn0xz8sItQ
# Track id added: 4X9MXfCcpky31EeMSiEvd6
# Track id added: 4psQvhuh4SWdSpWG3MBPDJ
# Track id added: 7mZliakmeP3a2MIUO5E95B
# Track id added: 1AvFLos2LmUJ6yD8MZkWMp
# Track id added: 2IIRMVR0pYXzPHOBLkBjpp
# Track id added: 7h32tZFHxN8FJe4Zklacpx
# Track id added: 35QHX5MI7JpB0xwX4HZ1Df
# Track id added: 1YnewALtpmHPZg86MgB1C0
# Track id added: 4TukRRGZFUSq5kPwfyGLks
# Track id added: 69jh75pvII5TN9GIQdQTZb
# Track id added: 4BfXTFmRi2IC2eAfVQcaVr
# Track id added: 1KJGm3RXNeR5fQlj4yzBQE
# Track id added: 7iF7kPMRDUfJ2KiWvOunu9
# Track id added: 5FprJfHi50HxBk2vMmiGN5
# Track id added: 7FXrxmK48rpR6aIIUN1lXX
# Track id added: 7FrnUpd75zOUNyF75NVfmw
# Track id added: 3q41FyRfIRsRZi1XgMvPgj
# Track id added: 3SbJgLKyKVHhz2OL5KarUN
# Track id added: 5lLnDUK74pXYDLXEM6AIbe
# Track id added: 2JhoKa5bAvN3pb8YPHNS6T
# Track id added: 1Jv306ZKsvLGbC30oKPrdD
# Track id added: 2MMv054Rdg3EkXqBXarJ0u
# Track id added: 4BS7Mn4LOFp9VpniWgudd7
# Track id added: 2rZQqpWUAck365eYbTm5Md
# Track id added: 3FCShvRNGQU1agAnhsKcNS
# Track id added: 17Mi8KWXkEUhGRJbR5tqwS
# Track id added: 0afjioU4siN1PkSi2snu34
# Track id added: 6dZ7QWC4RlxkIRZF6Gfb2N
# Track id added: 2Q6v99PFx8sCipwjNE3RtB
# Track id added: 6yoehagX3DpFFFvsPVgYOP
# Track id added: 4P7PwwpC5Tx0u0NB9MdEAU
# Track id added: 7tqPit9HM6pKNzpnq7i241
# Track id added: 2ZDMI8DoWmkpQy6FmyJYE1
# Track id added: 5S1jQIw2G8IRdtQRf6LXjG
# Track id added: 7y4IHqlzDssrdgmVGEvVeL
# Track id added: 7GaEt0tHtVaL7ZucXAzMdZ
# Track id added: 0VCL4XBXkQvEPidbvOnmV5
# Track id added: 3MdzmOoNlvfkAqr96Qjjqj
# Track id added: 1kbJRQRuG946EhuhE2r6Ra
# Track id added: 5eMECYQnh7H6gTDCqQhyXc
# Track id added: 4AeHadIXCfZJHNXcRXlCDe
# Track id added: 11HCESwWdifTIJ9FGXK4ro
# Track id added: 6oK4e8m4cUyXPZWc1g3e0P
# Track id added: 6IklckfXzNIjHDK5PokMJB
# Gathering songs from id: 5QmW7zYwGfW9YZWBVKeqBU
# Track id added: 5Zw1QdM70Az8IBTYklVmZp
# Track id added: 08lt6ItXjbC2swOfHViSk8
# Track id added: 3FJRO9xrAjxHKVpwKv9U8t
# Track id added: 1ujjBV2xEo2Eq6LV41hwsW
# Track id added: 7dCnCDtYkdsXt4aVOZvY5x
# Track id added: 1NfHoVVp0gmjAbBMOQr8vv
# Track id added: 49dSDZ0YWHKiSAcSb7jKGe
# Track id added: 2I2u78wIMEdLvv3EnOxLkv
# Track id added: 7JzCGO8fgagRlcTcdvt6nE
# Track id added: 4P9A0voQi0ytwrXlHKdtWn
# Track id added: 5zzsFmH4sPxxCBFWp26N4S
# Track id added: 0waxFBKHXcS20Ghc0DwVMD
# Track id added: 3PdECNtBmGSsyuWS8MTBfF
# Track id added: 2jykLURk8FWGskNpeq0kGu
# Track id added: 0iAXKLHI0oXoktwrXA0iMk
# Track id added: 3RKEW4HMiRZQMXY63XSieF
# Track id added: 1O8FFruddXtdS97wBbsbqK
# Track id added: 7baKPNJlaNDTWmHIhqDg3B
# Track id added: 3MqLOmqRrMAqjCk1RFxgqf
# Track id added: 236PcMytqy6FoTZWThY2sl
# Track id added: 0Hp9t95klVUa4fWCs9AuHd
# Track id added: 45gtJ6OdU2IbrQUE5gzuQY
# Track id added: 7JOKS25bzEReYfjPvJTOCU
# Gathering songs from id: 2PY3V8CCFzhqxUzWEcjKZ4
# Track id added: 05juXovlgQVjCWj0VIclyz
# Track id added: 5AYlymHyBOYUvAwdVBUbRl
# Track id added: 0aQ1zqVygWUay9zpxrdQdR
# Track id added: 7kY4HfrEg2rpYMQ4yP0uEe
# Track id added: 3727E0irjaE8NxYRGwMHjj
# Track id added: 0JVMOaawbabc7avk6zz8Da
# Track id added: 2dW7bhnDQaZ1VDVp68Cja7
# Track id added: 4A2UXtNIwZlctTZBw2Wtji
# Track id added: 7LizhOyAw5eQSB4SN9FhU7
# Track id added: 5tm3o0GjSQXX7aZc9qD6Rd
# Track id added: 02PeXMt482sLcOMK2ZzSX1
# Track id added: 4cE1G9stVsE1LBLK76fqOs
# Track id added: 2dCSFWvZgMFNse2Axhd3kD
# Track id added: 4ZYRZXH8Xs0wMRbfn7vuky
# Track id added: 2RNuAPPiCnssVL9zdfbmmU
# Track id added: 20On2sDRVtFlomCIH7hApL
# Track id added: 28Ya2ySCHp9EvOG4nWjcHn
# Track id added: 0WrN8qy1JgH8iHZmXzTsE4
# Track id added: 06vwlz0JNt2Rp42njLD5Wd
# Track id added: 4TdvujLqCCiUfn2O1iaKRs
# Track id added: 68kEXpkts5FRGiO8D6FKY3
# Track id added: 4YZdQzhAHkjHoNlJb67nq4
# Track id added: 27hdqtMb0JCDW3Om66C20K
# Track id added: 6D9pELc0TWsCgxVxqhpmkR
# Track id added: 7naQuteqJRZjVe4YmMsuPC
# Track id added: 4yFHRAOqyQFDTGLOWiJKtF
# Track id added: 6TpLZJ44TA0GDxpJZI0C9U
# Track id added: 7EYeVdo8puq5kORKDZnFwJ
# Track id added: 0LBEdoTfp3hVDdwRTqxoCG
# Track id added: 3sGgq1Lqig56CQagEPz66T
# Track id added: 6bjIKWJUGlI4qoLWkDFwCB
# Track id added: 4BpoB5Ydv8WFjYfirK4l8S
# Track id added: 5AhyxtAJ8Wx1FWmsDRsmYD
# Track id added: 6JPyozKJ9TFe8R0KcTzy6L
# Track id added: 68t81BCsF4L5TnmGCUhdDz
# Gathering songs from id: 6UJNjW9qNBTqn1Z5g8TKs6
# Track id added: 6x92rAIFa0VN24pV4aW0NB
# Track id added: 4GEnEMDlvKz7yp0tQatQo8
# Track id added: 43vKmunRSkDGKl2pU95j2K
# Track id added: 5EFfzWeluVlsYMNNtgksE5
# Track id added: 3Zycppstl2HpOoFHW8Uq93
# Track id added: 34rkejQU7AIOwpblObiIBn
# Track id added: 1tai3D4fj1fpfAf60uKIy0
# Track id added: 7gMFt2JOuvBYRnsoOygCqV
# Track id added: 65c0lYFVFqKyGO5zUPy1mt
# Track id added: 5TWpjpzVh9hBtqjgSSKI11
# Track id added: 2Q6v5cFb4lKvZIBi2qlTyA
# Track id added: 1zkFBbowM7PdyoW06VdnQk
# Track id added: 2mYu773v53PmG8ORFkU1Vv
# Track id added: 0GGKEXIwznikLmZesJYfC9
# Track id added: 1vq2dNh7qLCBZL3TaMajZq
# Track id added: 7AI1fI0lpuc9111fXJAIfp
# Track id added: 3paYJlgpKeooFNSM9EnW5y
# Track id added: 4lMbhZz7qEboXs9lO5jvvn
# Track id added: 1IjodNyua39xxPVfhKGV3K
# Track id added: 77liOL9U7CpnDejyrXjOJ7
# Track id added: 1LJjiTNTBAFk6Qz4oaaWps
# Track id added: 7hM2lHWuKB0vqpqGPeFGS3
# Track id added: 5pfkXMPic83exXgs7ZLRyx
# Track id added: 5DmhTLga6jGVzBtzCfFSk6
# Track id added: 5kKZGVr9X5l9xvZ1JpNvr6
# Track id added: 5Vcqeg6ILa3vqlKrlvf6ND
# Track id added: 1nP9C2ZgsxQsTjTZhcgoTX
# Track id added: 3SSVtNu0sIYIXXh5HBeKLf
# Track id added: 1bddJhE02tKhJOdZtL1Opf
# Track id added: 6woHF6IbmoNlTbf0czfAPC
# Track id added: 5VH9YCYD29RRJQJ2Pi4CUd
# Track id added: 6XsYCqbzDarSe18e0ghlLF
# Track id added: 6yZqf4xhGZiJ8I2uvr6sZC
# Track id added: 0Hd4EipxQPU18dQbt3eWP4
# Track id added: 4CoMq4emKWVCuT3BxFdg3N
# Track id added: 5CmrtooIuAdeIPoIUrJ7FP
# Track id added: 0IBwiSWQs28JPdchTt3UaJ
# Track id added: 5jy2JskvHgIcVqfEX8AUFL
# Track id added: 1exM3R11zs10mfrYvrsRxv
# Track id added: 6X7Wc5rs15NlQ56XUUC4CC
# Track id added: 1KOoqZnihyrKV3H3R2kBvR
# Track id added: 6MKyKUqyeWezd19e7BkHFa
# Track id added: 1DkA0QzO8Dk1Dq78ZXyJld
# Track id added: 7MiyNzw3pZ2ASy1GZFg3GR
# Track id added: 3OUEtUf1Zj74zZI6K3W3oT
# Track id added: 3L50uN7SzEPRT0WhLngqP1
# Track id added: 4kxHYE8HN0KWwHiuN16AdQ
# Gathering songs from id: 4B9dJjZ4F00cExmGc2OiST
# Track id added: 1bO7kJh4HOK9dEX2I1N8sT
# Track id added: 0yOKgkcFiusvJB7jhtbdFY
# Track id added: 271vFN6C8h7pLXKhmj2r1U
# Track id added: 2N5sHK7snWsqQGswbfMMER
# Track id added: 1a9Navgn9UkZxxDxegUm0j
# Track id added: 1ccqUfxia5GOSGXumGXA6C
# Track id added: 3OW4iXeOO5ni8LjnOdOi3L
# Track id added: 5Nv0546FRFtbkbHhf78VNx
# Track id added: 0ujO6RaI9dGeY9KZoN2B7s
# Track id added: 5iXv9j4Xj8Xcsgm1wFMSZ8
# Track id added: 4sVAze585JwbedqvZHWWZH
# Track id added: 0IZnpZ9EhWJ0OlDzswkM7q
# Track id added: 45fMjgc56tJz08ulhQVpXV
# Track id added: 61ecwd5zVaiqb5I2Qv7tFg
# Track id added: 6cN8zCwVqenS5pBrtPH5fd
# Track id added: 6IeOMUCBkkjVOBtjmTWlbh
# Track id added: 1IW4bGvaluQwn2ntwlhViR
# Track id added: 0gTc1SKNmeKr0Uc1xcpin4
# Track id added: 0ic1nBmG0098eAykcwodFs
# Track id added: 1hst8wcHEZYbDFbrtjiOB7
# Track id added: 5bIdgVdZpg3LbjmYVL887F
# Track id added: 4xXy2BABXuo1DtT7lF1fjQ
# Track id added: 5eOA6CPVewMsW1VX5tIgUt
# Track id added: 2jR1673CP5uu0AdTSnoaM5
# Track id added: 6eIglBJABH9eeoMfgBbZlN
# Track id added: 3B6r2MJoPLlJLqlL9yAuvc
# Track id added: 0lXPIfKDVao0o2s8kHInyB
# Track id added: 3UqSq2kfxmyjkBNVREA52x
# Track id added: 3QXoFaoYKbkTBKBgSnsiTT
# Track id added: 7ATJP4Rm3vUlJzGFRxGnR5
# Track id added: 1dANbojCxj2EX3h4GNYS41
# Track id added: 7Al69ZvBtzu3B8FOIuxAk7
# Track id added: 6zBs2F6glBA3eagTIFgiYO
# Track id added: 40WhUk7U86T4eZENwW3b4q
# Track id added: 15SrUVPUlM07qvFWcMR1mG
# Track id added: 3ahsCqsL4JebhkiuYIGRyc
# Track id added: 6Kcz5ygUaN0xdH1J7CjWZr
# Track id added: 7861bmuhxbbbNgjbixvmt7
# Track id added: 3ErlN9OqlHIAk4MpNmE822
# Track id added: 7gQSDzW9AqwYMxBmYT3hXi
# Track id added: 6fo5IEEa5eln9FEeoHIBy5
# Track id added: 2hh08TIKyOjfNj8sDqREjw
# Track id added: 59e8U3Zr7Eo3KG9pNB4XSk
# Track id added: 1JlLEpTkziupVxM96RUBv8
# Track id added: 4RcXPlPqBlDWdPk18Sh3QW
# Track id added: 56wKkCN7Njv9lD0PjSAZvV
# Track id added: 4z2mxlLlzqXddwRNx9tITY
# Track id added: 3PCHt5cYf3LCYqyzud6szS
# Track id added: 1JkO69DLVci3YDL3m4vGis
# Track id added: 2oc8Hnq4ewPX1jJA6UUWxJ
# Track id added: 7gpIIcwlSeO2QrfryFaq4o
# Track id added: 3HWQcptA2icPwVOE59iojW
# Track id added: 6zdoyvtAdtHZwpNc3fcDuN
# Track id added: 0QFAu1X988zEBSyfQMSTjN
# Track id added: 4nfvh2NogmqvajU8nsF1IQ
# Track id added: 5Kvx9IZfwtVSaNTendhu6K
# Track id added: 3ylImZ282pKdPcSwj9AVu2
# Track id added: 3gO7b9Wr4uMDZKdjvCIaCt
# Track id added: 2kDStul1ruIU1isD1bJjrJ
# Track id added: 0KxRE208RZVFrjgHdJgx8j
# Track id added: 2aCCM5x7BTGS7al5kXXRM8
# Track id added: 1PgagICvhltxhrKJNl776r
# Track id added: 0WDtSmw68a20DXMHWcuuqb
# Track id added: 4OlsVMG35PdVYRMI5KIMHc
# Track id added: 3fQX9qfH116hQbIxcS33q5
# Track id added: 6W3Dx0IFRNapxYYAzBqM8A
# Track id added: 1CYXdsiTSbUjWgID9KTsiE
# Track id added: 35Dl6f7bpdhXVK0qzYyImk
# Track id added: 44U1AHa0ACG2Qu1sv8pIg9
# Track id added: 5ssYPfZPCIlH7AgaT4jnSJ
# Track id added: 6hauSC4uMqHuZeEWYpr9S1
# Track id added: 0XUbiNQntCVNPqfR3svayW
# Track id added: 1feq8k62llb2vAuhq4Q01Q
# Track id added: 4onjFSJiox6EptyHzNiPOt
# Track id added: 6gVqx2EEpQrN60E9IDzlWc
# Track id added: 5ae37YpZxWTLrUon6Q7ndT
# Track id added: 2gT63rFyJ5UO4EDZ4riBP0
# Track id added: 6tN5kC5RpK77rx7AoXLoqc
# Track id added: 5f8j8zmYx93zG3Cvz3E5T5
# Track id added: 5FzJr3mZEhOSFJmr6duXQ0
# Gathering songs from id: 3Tyez015JVVZwhnF6YFVOI
# Track id added: 3uqraT2GL4BqTE4o5Ov2MP
# Track id added: 06TAxcZAVj3beYYfuRbkff
# Track id added: 3s3gzzcckUQ2NWHuNuzfSW
# Track id added: 0AW4QP41ZUZ8O8HbOqkD8y
# Track id added: 1S59E0qKUoPdVneBH4nelg
# Track id added: 2TLCsKOS3cSKFQwz2Zzufi
# Track id added: 46Q4xDLqOdLHNLRBsnrbXH
# Track id added: 4ywA7NYEKJs13QWButdS5z
# Track id added: 5cnMcrmblGaBgR6ftd1UDS
# Track id added: 1i2UwbdSxF0IBHCO0QxNGe
# Track id added: 4zm6mMicokumK7Kbk3WEpn
# Track id added: 0LI2AM3wK2H9DS8NoBJrGF
# Track id added: 2cUjRoGBAKZZiBQXBHdhKj
# Track id added: 0QDNCz9NtJIQx5rvRWmFoM
# Track id added: 2LDUYsfmhAOrGj4ToNG8wk
# Track id added: 1dCwvAjKeDCMY15bVnCQ6Q
# Track id added: 5mfTP1xYhWpujU2xC1A9Ma
# Track id added: 7kd5eQxfZrLYvFA9GdsCti
# Track id added: 4QcKz6yb9bWGgQWkXySYVn
# Track id added: 6LNzRGBIxH32jPTtcVk7ef
# Track id added: 7at0GdChYyGGt9xm93pVKl
# Track id added: 3QPoqhLiCl79g7Uzgg91eA
# Track id added: 6J5Lbp7lLA6dVJZcioGXnr
# Track id added: 3laWtyrj078WapatyUkFYr
# Track id added: 0Plj8A0KtK1qtK4pfbSLbU
# Track id added: 5J7iI58NSIBoHVkxeg1vt0
# Track id added: 6qowZipZxczNKssL4362jP
# Track id added: 262Sx9twlJV3t7Zriw7UqK
# Track id added: 153miCmWgwhYFykzqfF20x
# Track id added: 3Lax7F5fNBGBitBD1KKiwc
# Track id added: 35PDGkGCjExDH2USd820nv
# Track id added: 2wuqk70N1bLrfdlZOPQ09z
# Track id added: 4tdclhMMEtn1VOVmmA6YJT
# Track id added: 36uO513qsV0wuVic5ZSENn
# Track id added: 1ZtbsptPL7iY2MFavbPoc9
# Track id added: 4pgJs59bfAEshUD8oaanza
# Track id added: 0clWNvNnXMNAVZKYQkku7S
# Track id added: 3i5yWfgpkThGz3VyKSEWmI
# Track id added: 1K1vxVtpeT7XXDq6zWc04t
# Track id added: 4p2QECopDSJANJwDPl10e5
# Track id added: 064ArjD8nY3VeIe1sv4RN5
# Track id added: 2odasZcygjXIMNNXZUT2TL
# Track id added: 3prAcUoFV7AvVCGRsMVpuP
# Track id added: 29Hw46y4Wp13FLACKUA1mg
# Track id added: 48FzjrTfg46gRJO05q4XTT
# Track id added: 7rk1QoEzHFQx84PvBSF8I5
# Track id added: 06wYXDaqYXAtRDtXBVNVYC
# Track id added: 1IXT4tvDN100e4uM7NOqot
# Track id added: 5N3SsQusQLKnwHj2PuUoII
# Track id added: 3lD8rQbkFZRXnySFSZ6t29
# Track id added: 7KwMl4zbIjzQIWgaL8lO5s
# Track id added: 7f8A6xPqZXTXEAoIiIz9AS
# Gathering songs from id: 4wyNyxs74Ux8UIDopNjIai
# Track id added: 5cOiYDeNCPodKA8a9eBKsp
# Track id added: 77W53vCJRWylQq5gOCJrok
# Track id added: 7F85TgvQJP56F4gjHZGIsU
# Track id added: 5bdpv99KytHA6poS9wK6c2
# Track id added: 26piNuNiuj1hmLZv5CvqYP
# Track id added: 11ltAe5mJ5OIPgYXjhDnqt
# Track id added: 6Es1MK7Gw9XxQWX5LR3Efo
# Track id added: 50ECu3ELBm97PmkumiABp9
# Track id added: 6iJ6JXAKqHJXusqZo4v58X
# Track id added: 72NpHF24my0vOvvuBSEOZo
# Track id added: 0mMM64DPUYcHEfeSESHFh1
# Track id added: 1EOnpNmIQCEavEQR0bgYTv
# Track id added: 1wcbgOlV8jt3azvHI3minp
# Track id added: 0jm3lBm4DeBihfM34IHeRt
# Track id added: 25bwZkZpTFsbFskpNq7mkT
# Track id added: 1Aa3nyVOWs1jPNutjJb8Af
# Track id added: 1oMAZKzCbxmVPkr6uWB9Za
# Track id added: 0p7oSAo7L1nPXxtGMH3BzW
# Track id added: 2tCS6GjYTRQP9uulNPTYaA
# Track id added: 1jk6tbx0xFuEq1eHGTDMv3
# Track id added: 37NhTqdEWadpZ6tdYOtI6w
# Track id added: 6yV1FfhbkfaLaagGogMGfG
# Track id added: 4xsZbJalsgOCfG34HBebZV
# Track id added: 4A63LckcnvT7abzQxjDqIJ
# Track id added: 1gEIHGA6lHfGgWQXnF0dJi
# Track id added: 76tj4lRYQjKfFojEDHgsuj
# Track id added: 1Dvqeu0U8P5tuPSIraHlQI
# Track id added: 4KOH4nF3vtcLbcpTLkTtBS
# Track id added: 4X8Ovnp0si4JF43zQVDngF
# Track id added: 6alrVz4PGYaWuxwHzrKSIo
# Track id added: 0UiwfsgfkttWrUqGLV2qZH
# Track id added: 5650dsaBmvp9FuhCLLyijB
# Track id added: 1k0zj8ZVlKUASbhhkmutro
# Track id added: 0MyEjgnuBTLjfOmURATpOQ
# Track id added: 0pSL27waKpGcywLYWb7UDA
# Track id added: 1Iq6DFCVez5u5rHE2TJqvK
# Track id added: 41NN5x5JhZFG0GqNbscJDP
# Track id added: 7zU4eAKXYbQ8hleYDXcov2
# Track id added: 0MNyneZBpAC3nj9YurA6j8
# Track id added: 5A4P0HXluOB7NeEhzMzCKG
# Track id added: 7nhoOoBjLXVx1FadDQmDNd
# Track id added: 3z6ocW0ewr4ji7cqRDtDgq
# Track id added: 3AA062igZ9maW6zrCh5M3p
# Track id added: 73YamekX9jhQu5r2sLf2uF
# Track id added: 6G1TNO86E54Mnvyvmq8MFl
# Track id added: 1r7mKWfuGQm2NMRKsgVL5c
# Track id added: 0W3UbBmbn091SenRDJgnoB
# Track id added: 1TyhYWRusbue2YUVcc5Mrh
# Track id added: 5wogkmCiovgDIbUqSJGMti
# Track id added: 7z41WUzSJJvvNfw3BO7GMZ
# Track id added: 3iZLtD344l5FYBmJTmEheF
# Track id added: 6lHz9vaD9fxEHJnzYkN5Nq
# Track id added: 0VECxmcrec9ag2DmZL55dP
# Track id added: 6Zuvmb88BrTL6kzuofj97x
# Track id added: 2jziViBlNQGK8StIFN5Lub
# Track id added: 6Ko6VLnveSju6IZiwONLTt
# Track id added: 7pb3vjNwAzuUn0b7C8htrI
# Track id added: 40mSZC8nICHinefxni5Usv
# Track id added: 4aDwqL696Kq64wPF69gJ0n
# Track id added: 6ViyHpa1odsdRkw34vgiAf
# Track id added: 5EB1a0KP64PQe6UF3nCA3q
# Track id added: 22eG81kHWrkaUFFVrWtzEj
# Track id added: 30JUrbIq4PsRjIvDz8freE
# Track id added: 37Y4b4F4UulmLW09HmbWto
# Track id added: 1wXbDJMiHEO9vfwVJPOBcH
# Track id added: 4RqnJUYxBK1jNd1fUrpOMB
# Track id added: 25Ke6GfR72hvkQAt6fjM7j
# Track id added: 04NJEtg1Wj3oMmghmEECPs
# Track id added: 7tCmJ3uKmwBi4WBoYNrHYr
# Track id added: 6w5VbMZwwXvQFDcshBu7Zw
# Track id added: 5UaRigJg6qYQT3jFiXem50
# Track id added: 3aUmK405o4N71BVYGLFyDN
# Track id added: 4VmU4sTfJ9vLLXyP2v1Rqr
# Track id added: 611frQHXvI1RZ5Fqk5k3T3
# Track id added: 6iA8nP6lHCheMe1fPJ04Ym
# Track id added: 3EUZvtc8LFHELEJRLOHYY1
# Track id added: 2Z2kgWurEIbhILUdFrW604
# Track id added: 14JMeamQwgU0HSYgj77JgF
# Track id added: 264BulADOZekMedSte4LDi
# Track id added: 6bSJ8NYOKmInYsDnFDqatv
# Track id added: 69oBxcxmMI4xPtR0IXYgXk
# Track id added: 1MtMZ8lLNbZsDMwApwymaA
# Track id added: 4fkMnNG2vxljkanusCCbzI
# Track id added: 0Im8PvGcYOc57KYy8QCCkp
# Track id added: 5YiUph3jpcaJ8JHkzITUVb
# Track id added: 0J42oDkvB3fUDb95Rqcukl
# Track id added: 63Sou8flpqXs3ysfvzedq7
# Track id added: 1I9RYIoekh5ldCTYfWOFRf
# Track id added: 4gybief7CjwbtlAfo9HIpm
# Track id added: 7vWj1GAL7n1kxbcNfaKYiq
# Track id added: 1lKsho36aTXAzxsVZl0NFd
# Track id added: 2EGKjYTCrGhID7yITGi8kG
# Track id added: 4wuMEd3GPbLjidyQOpJ9Ys
# Track id added: 52F1Vwr53uLC910P0jvE3n
# Track id added: 67hYvqMu0gLzGZVttwmhLI
# Track id added: 3fg3AlWTFgrxOI20mxwzpB
# Track id added: 5nsWJAj25ioh5Af6hHcgX6
# Track id added: 4NMQVBwbOafKNI04sSBmpy
# Track id added: 7eoNMW0Q6ucXW6gQg1YS7f
# Track id added: 3aMSHc6o4cTJnimrHoNT9k
# Track id added: 1dh5iHIq74Zq3H1hd6WCmT
# Track id added: 6DSfUltWc0D0WYiIAeKZ0D
# Track id added: 6SXcWDjgltK4FKH7GGZnqy
# Track id added: 42rzGiopJljAAAPqS9zEnx
# Track id added: 6NYTeny0o2kCZNdCmMKsSz
# Track id added: 1kNyzVL32OGhz4wOANiL8P
# Gathering songs from id: 0Y6dVaC9DZtPNH4591M42W
# Track id added: 20pi3c6HXmaEeElCswISpD
# Track id added: 0mY36ZkUABHCLSARBd3eFW
# Track id added: 6EJkSSM4zBJW1AMCLnnXT8
# Track id added: 4ydTfdsz2oByCT3JVOXVzv
# Track id added: 1LTBpEzgN3dplgZG2qo8bO
# Track id added: 3MUkijIqsNm4XIq3EerPpt
# Track id added: 3Sc6qFrWfl1OMUPqtCYRMH
# Track id added: 4ejHNCr4feK3bSxQnTgv9d
# Track id added: 0mzwDjT0KbyLtgrppF8lrW
# Track id added: 4piogK3cNW6mL19K8ItkB2
# Track id added: 26uHXNWafzDn8SkYB7fZ2r
# Track id added: 4EYGx9dPdBKpUm9Gda2tSM
# Track id added: 36TB6pTzZq0qnFOlFbxbZH
# Track id added: 6lbYoBYA9ApnX9pUIS1GAL
# Track id added: 7o5wXqVK3Dw1MDx3lFb3g1
# Track id added: 3VxgzhWzZk5HbjHelm2ZfW
# Track id added: 6BDj2nF5Oq3M3L7gXcHRcJ
# Track id added: 6FC1exmubGY0fIAJTsA302
# Track id added: 3qsctOMzL1FE9mBpt4FZHo
# Track id added: 1DPjbMypYp80indlQFWlya
# Track id added: 2Eq0Kz6bt24mgQxZKBb4LT
# Track id added: 4NUhcsz9E1LrBe8nXLZqzp
# Track id added: 17DmHV1rOZRZht3yszHOlP
# Track id added: 0tTAK9lTYMdlDduc1ll9vp
# Track id added: 59DxXc2Y0Pwre0TgnZpsQd
# Track id added: 2ua1rdhvncvBqACxCfTxL3
# Track id added: 2vVXZKnEIU5j0yVDGQX46l
# Track id added: 1EKDVrhKvTdI8tIJ1oGyii
# Track id added: 39sDitIeCMrVX2QyXHY46t
# Track id added: 18YXp2sVwm3Tzd4bm7PkMN
# Track id added: 51Hxez2vOWDH8HBDK42Uxp
# Track id added: 5PaCrBjL6W6Gq60kJzuw9y
# Track id added: 2eL2UEYxEfJH9DaTDoQlsg
# Track id added: 37FVobI6ZrZwD7QmXTHRR3
# Track id added: 7eClhHlXfHnMwZdR281GlK
# Track id added: 6rEwk32I81z6lIzOSCwwPH
# Track id added: 53mChDyESfwn9Dz8poHRf6
# Track id added: 5ExWCOYjZbMEZCIdlfH2dO
# Track id added: 6QeYSvYqYUsfBzsApbjDHO
# Track id added: 7GALElZRLEkzaxZJ7TA0I3
# Track id added: 3IznIgmXtrUaoPWpQTy5jB
# Track id added: 0N2Nx2lwHuqA203ZXoTwQL
# Track id added: 2c4Est3dxGfn834VReid5d
# Track id added: 4KHnHCB3KVJeQRHt9PM8uz
# Track id added: 7JEzAlwHhCD2M1cYE6BeqJ
# Track id added: 0REaf0xqIOxEXGZgOXfrCW
# Track id added: 7m6xr2HY0BYmBDTh2UIx02
# Track id added: 21LkHnuxPxVrOZ5gCaG7aM
# Track id added: 263KsGZODTZouh3RFGNaLX
# Track id added: 7ijyGfG4NxMBobHgvu4lIM
# Track id added: 5trzBtLlKIYZSmkbtkNmXb
# Track id added: 2SXG2Vmtn4S1lsbQkuWKBS
# Track id added: 72cGBEqu7RitIOoACXYjfR
# Track id added: 5cct9ToyRPLyfELg3JfWqx
# Track id added: 6dBUzqjtbnIa1TwYbyw5CM
# Track id added: 4YhMaKfdp5MgcECm2YC7ve
# Track id added: 5tPZxJzgR75cBrD9GyEVB4
# Track id added: 2C8BawsbZROHDBUnobEbTQ
# Track id added: 5U0OjzvvV7iGXvKStG41iH
# Track id added: 6oZ7fDtbmdX8VmB3Z1hhPX
# Track id added: 0JB7DcI1AJZUaytdPQll0Z
# Track id added: 36RNOJkIDAoyfEOHdLhmD3
# Track id added: 0uQ7HycayQUrj7Y8eh9OK5
# Track id added: 3D8aCumqG5rdGNdQ6a9RZ1
# Gathering songs from id: 1bwUhKRmEkOZ1wuTnV9XjC
# Track id added: 5nkVa8Ty6fMTlAOPtCQI6f
# Track id added: 3icFy8tUFi18GqajbncAXR
# Track id added: 1VEPFoEm9xlsPsBN66RpSx
# Track id added: 3gH0Ie0CGZtbSFSkbfZXh0
# Track id added: 3dDlpFSNNM6Sss2GHYrUi0
# Track id added: 7HwD5SOYTopnCad8V9tqAu
# Track id added: 43Q7lBeXEkLdJ2lZffnYAf
# Track id added: 7yE795Dx1OqWWKGCDFu38y
# Track id added: 23nrdVAFpoGPybQaiM1xg4
# Track id added: 7hWeviJOyxDksLcnvBMsZA
# Track id added: 4nAsSTHuIcpWYkNjI8pacI
# Track id added: 36bVcRltxiQSg0ZEHDAZZ1
# Track id added: 2Tqpc6xSJ9xvNzaaZh5f08
# Track id added: 19uq4pCZON9cE6BzzlBUks
# Track id added: 76JpSbkjuUWPkdSGQBjd2w
# Track id added: 2an4tvT09r0qWEWYWfR2BI
# Track id added: 05ZUxHiGT7VR6ShJjhwJxn
# Track id added: 4jvVHt4UCgHc4Wi1wUahVn
# Track id added: 4Zpz6C3vYEZHGJbpSy3ncW
# Track id added: 4uTgUb3XBqxDBBqRJiEjTZ
# Track id added: 5KTLASVVZDSHGBtjTT7RBr
# Track id added: 4OF7Mx4DnLuyBuHo5Ks6sM
# Track id added: 4Qwk3fsqLPnoXe7la6s4Rw
# Track id added: 6xahp2UpNMA1sjzajU4ynW
# Track id added: 6T7CPzVfFJ7ACO6G88g8q9
# Track id added: 4UWM3oR5v07LdrV8fQueqJ
# Track id added: 36dwSMtI7MIsjPWMrlckBa
# Track id added: 3rqf5x3tUPCAQytog6Y01w
# Track id added: 6XyjwF7CAwuEaW77noJr6I
# Track id added: 1IwpF9prgah3j8WQLDhaW4
# Track id added: 4CS2VwPyGHzipUAeIpCTaV
# Track id added: 3PG2hAJHox2wkGLNtbwvgE
# Track id added: 59GPd474r6bWkkQSAJDDvI
# Track id added: 6tGkX9IO7mOY36rQRXpvGF
# Track id added: 19JDNzDT7KtFY7ZaFjBmqA
# Track id added: 2lgTJem8nbBgkNKTRAi4PT
# Track id added: 7jB2SNoO0OZvRLH9IfnrX3
# Track id added: 4uZXZbMOiOwzk1LF9PxUkh
# Track id added: 44T24Si6NJZi4pPFQKcy4J
# Track id added: 15zHnnhko77wc671Cdf6Sq
# Track id added: 29j2rxCOzniEX0N9UgwzYI
# Track id added: 3FwuOIr8dkrzdAOMUM6sOe
# Track id added: 0zeTBtiele34bMeeKfiVOc
# Track id added: 0j5CR3SWQQuvmTJffDmD0g
# Track id added: 1CR4t6qFDalQGcvbQDLXiS
# Track id added: 31gDnWmoXSSA5IGjNlZw9x
# Track id added: 3Idm9G9zoErHzzWEBYxB0c
# Track id added: 7nMJz51yr8zQwk3fn051Cs
# Track id added: 13VLmkYekcDDyMWvg9NZ06
# Track id added: 7Ik9HVDYvyerTggtHiqaTy
# Track id added: 5YQjYLYLbWcKdYMkqwfwco
# Track id added: 1m10Wen9M2gLMIzZQAkZls
# Track id added: 552M2IdjwbC74k21fyludl
# Track id added: 0OfmbCNXjiI4IxDQ6QI6vM
# Track id added: 74GD6suTSjgsrdpLkjiXtf
# Track id added: 7rIrl2nCrrYXetLRRS9lka
# Track id added: 3VL9me2vrKIzcLhMluW3rx
# Track id added: 0I192Kj5XHvwPU5NTIlnyJ
# Track id added: 0mGD0EVPBKqNEOUdNgfBUU
# ...
# Track id added: 1w9GzCUF7X2YyPut8upFbu
# Track id added: 4rrvMZewjtxsoxn1izzh7p
# Track id added: 4KhQ5AbM2qiL61Fo20oK1a
# Track id added: 2OhXoI007F5hCK2zvBoE7s
# Track id added: 6QVmA8sf65PsuZhgQC9kpn
# Track id added: 4X5gbg8xYAKlfK4uEiWMVO
# Track id added: 3kvR8A0Jlqz8ovhzamXxUb
# Track id added: 7wM4AmgWdphAk6y53jaB6o
# Track id added: 3UUHIJkaaCWTROilHBaUy3
# Track id added: 3JuSKC6iDWR3CLMj3VDpI4
# Track id added: 3FV18JMM8jd0FQYP1jU2Co
# Track id added: 0yWhtDnI5VQhGANgAeCKvb
# Track id added: 5ykuWhTlXoVgDW7V5zWNk2
# Track id added: 5QOS0drmKbgaPlxxgCNYL9
# Track id added: 4sFC2AVfrbTLNJiPMUMkg1
# Track id added: 7HUf4C7RaIBcpsdImurjqQ
# Track id added: 19KYm3dwuXtnCJ8CH7jir9
# Track id added: 7qxURPGc7EXM1G8I1MYuDU
# Track id added: 3uK25chay4EBh4VcV4Pj4e
# Track id added: 3m1lEqDZwC03qNtZ0CqwKR
# Track id added: 5gGFXUCWf9eeGrlUpXbd7Y
# Track id added: 2yXUeAgpwauKbtypPA0zQY
# Track id added: 1D9SebeMXEghqac62WIYjE
# Track id added: 1yt6VBxgLeIrPfEhKCfVJg
# Track id added: 2ouUY2kuc5HJKYnj0RiH3T
# Track id added: 7eDTV1I35HwBcLfMCHHCxZ
# Track id added: 2Sgbq6uWkY5Qpp0w8Ge2Jf
# Track id added: 5xDvEOrX42bqxG2wTJyo8p
# Track id added: 1TNuiXaWL3qEq5RLdNiJ2z
# Track id added: 33JjQn8ZdMTneIcPZMgmG1
# Track id added: 18DFlgkNmDXu9lpmwyi4Wr
# Track id added: 0RgN9EyqmSidaxvcGFY6Nq
# Track id added: 3gT3Is6k0CHIldsr2vtgHM
# Track id added: 05OU1LjxNp7S0PaXgqEizq
# Track id added: 2ivFvHaimsFOLvvJBch4oe
# Track id added: 0EWSCZVZaC0v5ZkkvPYHQp
# Track id added: 5JWF61820kz8i3M3BIruZo
# Track id added: 30LRB5iJmikKkTkK0SuOhl
# Track id added: 7xQvSWBzIAu6dsK3D4eg1H
# Track id added: 4snhjqewxgIeUgFjaEh2kV
# Track id added: 0HqMf9L6Jw56Ol5OkDY7lh
# Track id added: 3BEPWwdCabug0QzyTH1L1B
# Track id added: 3Gm5JpNaiwph1hzZYBEEs0
# Track id added: 620NgzgKMhLaV9VE5CXbOJ
# Track id added: 3ykfnWlpkTE3mdxJtbfzFB
# Track id added: 3uZ8jXufjmahIOlU1qV36X
# Track id added: 26x0QSHL77Wj2Gxrd2b9tP
# Track id added: 0jRrJP3HhcVXMDoZXgFZsj
# Track id added: 5VknQtdsLeYJufH6550Ww2
# Track id added: 5JASInKnqp9OCP2p73K1QK
# Track id added: 7evO6uOq4XxXkwn3Leb7gW
# Track id added: 4Zs8mSQeBZFslNZCJVg6fb
# Track id added: 4A2ZvOZhLryhHdG39L7V2v
# Track id added: 1ZPoQ7NImleH5Enu9e4Jqh
# Track id added: 0Qf81i7MFA6lWyWgKsZ3Il
# Track id added: 6zBU4RWdiJuBR08PQs8jFD
# Track id added: 4FTJj9p5AEGfD4dXS6Oevi
# Track id added: 606RzaJlCcsxrsh0GOLWs7
# Track id added: 4XkeQUYE7fT558H7lSQ82u
# Track id added: 3du68Yd6Vs9r1r0WIJP1cx
# Track id added: 5TpY1mD0AdIWTlEeNYUmA1
# Track id added: 6UyezUGR4ptnzrUEaFL9ZZ
# Track id added: 3Oix11es969FyJx3VLPIpP
# Track id added: 2DDgrA8cnqEr9Cs8ODLi0y
# Track id added: 1SRLCb27tb8ZfJWqpt8I30
# Track id added: 3QsYL54DS5yBk7gZwSoOzN
# Track id added: 6H53avkqQkf92ASrHONGVH
# Track id added: 21Cg2uEuiN7RLpMJSn4u9Y
# Track id added: 32DlE0R4tZ5KEjMuFtolCs
# Track id added: 0HKcNvnVBId95FZJwbG1ea
# Track id added: 445dmDN5uofIGycS25YmVQ
# Track id added: 5zUAiK38KuhA9YL2WCq78u
# Track id added: 4l47RetEkDVB6gr0tABsI8
# Track id added: 5ExsNndunkSfuNlU3foaVP
# Track id added: 7tJDiGPtCy3pHhHGE9pQzL
# Track id added: 1FMMHuTzV08oqThbp2y81u
# Track id added: 6Mm65plleIGsM0tS50nBED
# Track id added: 1tmsTVUREiW97ZBCQpKCaK
# Track id added: 68yHKLeLhDBY6Zyj4VEZWg
# Track id added: 3BrGH23qUUrEbgEYNwSY1H
# Track id added: 7w4BgRVMieBcBhzQlBM90u
# Track id added: 5Blqwwp1y3l8qCyi3eAV40
# Track id added: 1xRffIsWreNYwowWNM8Jlp
# Track id added: 5I85ffskLcbzoQe8ulU5h7
# Track id added: 2LlU1kmOdxsRKUL4Mw1Vgb
# Track id added: 68X3WOBGF70fYncrB0cmvO
# Track id added: 2LGRxnZRJR1F5mfZyA6PtT
# Track id added: 1UzrUslsbVEV6pjDhMzD7Q
# Track id added: 3iURmNo3J0jMb29Fk4mkbo
# Track id added: 2zm3tg56nwqvVwUQV4FTMu
# Track id added: 7oVXUeIqLsSlAc4ZITPMfB
# Track id added: 0OSAp4ELMvokeRtIciC4eq
# Track id added: 7e7idONbYIipgowgIzEHyd
# Track id added: 3ObVVgczop33kXFPjVOgva
# Track id added: 2dfX7QJDHrKMMxmEpMFDvg
# Track id added: 3UaTG65SHvkHd7ie2l2iEp
# Track id added: 6vTwjXjertFKTsZwuR5vxA
# Track id added: 3sTdhaRS96JYpA8x9Xdmxp
# Track id added: 3oQTfdj4f2BuORLm3bwjyC
# Track id added: 3v8RwnYDGSjRFhLUuEC9cN
# Track id added: 22PoJcJZnKl015Z0GTFIpc
# Track id added: 4Igih3fYIYmjegdqMjVWjF
# Track id added: 3ISm3ct7YudJBagPl3Un6y
# Track id added: 3uQZHLtCZPIyf0zmzJvY3l
# Track id added: 5vLDo7gTCbUcB4IXKZLTec
# Track id added: 1HXDYDOxKVdWq3tvwic2K6
# Track id added: 0z6M7jZjJiTgvEWa66ot3e
# Track id added: 3gmlPnScs2g2PVaO9qdaYb
# Track id added: 035nTC6nSRTnrNqPi7oF7F
# Track id added: 366jXc7vFEiuzZDds7x17G
# Track id added: 0qI9Nd3EIZPW2ZZNkgoRHr
# Track id added: 2EqlhOgeME8umJpin17uOT
# Track id added: 5pH886tuE2aY2vfsLzqWI0
# Track id added: 0rb3erIfiITWDBH1JITKbZ
# Track id added: 5T7UBrspIe9tCPN011Xnxz
# Track id added: 5dyXHG9DuYBj5Fl0mGtIxn
# Track id added: 1wwTiwVmUeKAJwif1JB7rU
# Track id added: 1GpfLSjpoHX8La2jpxwbpq
# Track id added: 12gsk5vCFPcPxJXmcoFOgm
# Track id added: 2HUMxqGxumQ0me2sL3rQ2C
# Track id added: 5sT4CW6ysgY7dooj6Fqs64
# Track id added: 2ZOuqwwlv1nEPENv5SFOOQ
# Track id added: 7gqKerAzASFeCTIhjJRa9i
# Track id added: 2EJYNFb4IyRn4IeFqCfcZV
# Track id added: 1UvNUkML2vH8Tyo7McH9CG
# Track id added: 1MJW1iyY84RG4OJbPoC4uE
# Track id added: 2LSyV88hluh3lk5D7CxIZy
# Track id added: 4StTt9SuQPSLz2UOxKcCPg
# Track id added: 2KoVHEmg0esu2QiDuM4XG8
# Track id added: 4lhnDjjrNnwM2gRoogJdql
# Track id added: 3gGwugXmieH7H6PwhisMMn
# Track id added: 3MyxoHHorXqb0t1f2BTcs0
# Track id added: 1ALtihXpgbWDXt8FaYyEPQ
# Track id added: 05khSchlAiZnskYtvt8Uhp
# Track id added: 4Z26g9JfSxiVSamOUzdmNk
# Track id added: 3gQAt3Q8pakB2nkRX4CzJp
# Track id added: 2Lf7be0Gccg1uTpLoDITWe
# Track id added: 0GVrvIGVJbmZsNHYVUXEVN
# Track id added: 2uipz2sNUr8r10rpFMzkqJ
# Track id added: 28n0MT89Jrhg8ah1YDkPOs
# Track id added: 7jJe7fCa2Y8B7C5Rb80RRL
# Track id added: 398a2tqgq7AUNh3PETjeRD
# Track id added: 36fh1XCQT1bcRqxVKOtwbk
# Track id added: 0ziIaZNdX37RMaLnmqL00z
# Track id added: 38iolooR6LddLK1GILWNDC
# Track id added: 48bbrL24lngzlyRUe3FM0r
# Track id added: 1Q3YY1FNDzx0Dj6kLKCgW2
# Track id added: 2tYPuZM2FtJQQNyL8i3NrV
# Track id added: 2GnWv5HrW0EB9XLpXxbaKU
# Track id added: 1SWj7M8xpE6pvG7vi1WsQs
# Track id added: 4y9WOA0nmA9EdrKsj0OwE7
# Track id added: 7FRNVoUxhsKPe73UfyRTot
# Track id added: 5O3WSnNsAZyHdtuonIIHEE
# Track id added: 3jTTbcrErwWxlEiIvvYza8
# Track id added: 7rRDDN7TyGKkRAdtCwNAeB
# Track id added: 60oXDmsqlKIQEh1eOcUVnW
# Track id added: 7yladKzWtWi4tkwUytxeB2
# Track id added: 65VLiHKZlRvoLqR1p4gcIf
# Track id added: 7r0ilMjXq9dLkiNAXZgcbz
# Track id added: 5eoTTBqKSLgcO8CZ5pOVJt
# Track id added: 4i93JSawJVKYbAlji0cssN
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# C:\Users\Henze\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# C:\Users\Henze\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# C:\Users\Henze\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# C:\Users\Henze\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# C:\Users\Henze\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#
# C:\Users\Henze\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# C:\Users\Henze\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452             raise
#
# C:\Users\Henze\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     340             raise ReadTimeoutError(
# --> 341                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# C:\Users\Henze\AppData\Local\Temp\ipykernel_31436\2779184172.py in <module>
# ----> 1 mainScrapingDriver()
#
# C:\Users\Henze\AppData\Local\Temp\ipykernel_31436\3135762458.py in mainScrapingDriver()
#      20
#      21     print("Scraping tracks from collected Artists...")
# ---> 22     scrapedSongsDriver(scrapedArtistIds)
#      23     print("All tracks gathered. Proceeding to analyze and select songs...")
#
# C:\Users\Henze\AppData\Local\Temp\ipykernel_31436\578094954.py in scrapedSongsDriver(artist_ids)
#       4         print("Gathering songs from id: {}".format(artist))
#       5         artist_tracks = getSongsFromArtist(artist)
# ----> 6         artist_track_samples = generateSamples(artist_tracks)
#       7         writeSongsToFile(artist_track_samples, "scraped")
#       8
#
# C:\Users\Henze\AppData\Local\Temp\ipykernel_31436\965787741.py in generateSamples(tracks)
#      25             track_id = track['id']
#      26
# ---> 27             analysis = get_audio_analysis(track_id)
#      28             time.sleep(2.5) # avoiding rate limiting
#      29             for att in analysisAttributes:
#
# C:\Users\Henze\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      54             @six.wraps(f)
#      55             def wrapped_f(*args, **kw):
# ---> 56                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      57
#      58             return wrapped_f
#
# C:\Users\Henze\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     264                 if not self._wrap_exception and attempt.has_exception:
#     265                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266                     raise attempt.get()
#     267                 else:
#     268                     raise RetryError(attempt)
#
# C:\Users\Henze\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     299                 raise RetryError(self)
#     300             else:
# --> 301                 six.reraise(self.value[0], self.value[1], self.value[2])
#     302         else:
#     303             return self.value
#
# C:\Users\Henze\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# C:\Users\Henze\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     249
#     250             try:
# --> 251                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252             except:
#     253                 tb = sys.exc_info()
#
# C:\Users\Henze\AppData\Local\Temp\ipykernel_31436\55621786.py in get_audio_analysis(track_id)
#       9 @retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
#      10 def get_audio_analysis(track_id):
# ---> 11     return sp.audio_analysis(track_id)['track']
#      12
#      13 @retrying.retry(stop_max_attempt_number=3, wait_fixed=1000)
#
# C:\Users\Henze\Anaconda3\lib\site-packages\spotipy\client.py in audio_analysis(self, track_id)
#    1669         """
#    1670         trid = self._get_id("track", track_id)
# -> 1671         return self._get("audio-analysis/" + trid)
#    1672
#    1673     def audio_features(self, tracks=[]):
#
# C:\Users\Henze\Anaconda3\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# C:\Users\Henze\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# C:\Users\Henze\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# C:\Users\Henze\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# C:\Users\Henze\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     576                 raise SSLError(e, request=request)
#     577             elif isinstance(e, ReadTimeoutError):
# --> 578                 raise ReadTimeout(e, request=request)
#     579             elif isinstance(e, _InvalidHeader):
#     580                 raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)

# %% [markdown]
# ### Producing Reccomendations

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_songs = pd.read_csv("Spotify_base_data.txt")
similar_songs = pd.read_csv("Spotify_scraped_data.txt")

merged_data = pd.concat([top_songs, similar_songs], ignore_index=True)

# Identify the column name representing the song identifier
song_id_column = 'id'  # Replace 'id' with the actual column name

# Filter the dataset based on relevant attributes
relevant_attributes = ['id', 'artist_name(s)', 'song_name', 'popularity', 'explicit?', 'duration', 'loudness', 
                       'tempo', 'danceability', 'energy', 'acousticness', 'time_signature', 'key', 'mode', 'speechiness',
                      'instrumentalness', 'liveness', 'valence']
filtered_data = merged_data[relevant_attributes]

# Create a user-item matrix
user_item_matrix = pd.pivot_table(filtered_data, values='popularity', index=song_id_column)

# Calculate cosine similarity
similarity_matrix = cosine_similarity(user_item_matrix.fillna(0))

# Get the indices of your top songs
your_top_song_indices = [user_item_matrix.index.get_loc(song_id) for song_id in your_top_songs]

# Calculate song similarities with your top songs
similarities_with_top_songs = pd.DataFrame(similarity_matrix[your_top_song_indices].sum(axis=0), columns=['similarity'])
similarities_with_top_songs[song_id_column] = user_item_matrix.index

# Merge with the original dataset to get song names and track IDs
recommended_songs = pd.merge(similarities_with_top_songs, filtered_data, on=song_id_column)

# Sort the songs based on similarity
recommended_songs = recommended_songs.sort_values(by='similarity', ascending=False)

# Select the top 100 songs as recommendations
recommended_songs = recommended_songs.head(100)

# Print the recommended songs
for index, row in recommended_songs.iterrows():
    print(f"Song Name: {row['song_name']}")
    print(f"Artist: {row['artist_name(s)']}")
    print(f"Similarity: {row['similarity']}")
    print(f"Track ID: {row['id']}")
    print()
# Out:
# Song Name: 29
# Artist: Round Of Applause
# Similarity: 149.0
# Track ID: 2oo7
#
# Song Name: 45
# Artist: All Is Lost
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 46
# Artist: Arrow
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 37
# Artist: Cathy
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 48
# Artist: Sugar
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 40
# Artist: Lost Honor
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 44
# Artist: Self Portrait
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 37
# Artist: Unwell
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 31
# Artist: Strange
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 44
# Artist: TVI
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 34
# Artist: Little Rock ‘n’ Roller
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 30
# Artist: No Tomorrows
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 38
# Artist: Fear City
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 37
# Artist: Randall Flagg
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 56
# Artist: Maps to The Stars
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 44
# Artist: Labyrinth
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 37
# Artist: River's Edge
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 48
# Artist: Midnight Cowboy
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 43
# Artist: Hour of the Wolf
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 35
# Artist: Dead Ringers
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 54
# Artist: Safe
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 36
# Artist: Memory
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 40
# Artist: Opera
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 37
# Artist: Trust
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 35
# Artist: Jamie
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 44
# Artist: Christine F
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 39
# Artist: Doom Generation
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 40
# Artist: The Strange and the Kind
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 32
# Artist: It Followed Me
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 36
# Artist: Cronenberg
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 29
# Artist: Sleeping
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 17
# Artist: Well Off
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 17
# Artist: Nun2me
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 43
# Artist: Woosah
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 23
# Artist: Fast!
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 26
# Artist: Is U Skr8
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 26
# Artist: Do It Then
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 30
# Artist: Die 4 M3!
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 23
# Artist: Model
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 25
# Artist: Flee
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 26
# Artist: Bella's Interlude
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 27
# Artist: Od
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 22
# Artist: Jiu Jitsu
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 23
# Artist: Fucking Geeked!
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 22
# Artist: No Regrets
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 25
# Artist: Got Yo Back!
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 30
# Artist: In Luv / Not Ok..
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 23
# Artist: Do U Like That
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 21
# Artist: Rollin
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 25
# Artist: Must Admit
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 26
# Artist: free sosa
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 28
# Artist: Fall n Luv
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 24
# Artist: Guitars n Melodies
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 32
# Artist: Think Of
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 28
# Artist: Ifykyk
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 26
# Artist: Bidness
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 41
# Artist: Buy Whatever
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 36
# Artist: Thousand Miles 2
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 32
# Artist: Ball Family
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 35
# Artist: Later Not Bye
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 20
# Artist: Highest Peak
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 30
# Artist: Love Scammin
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 18
# Artist: Trisiana
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 54
# Artist: Nostalgia
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 32
# Artist: Falling Apart
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 33
# Artist: Opiates
# Similarity: 149.0
# Track ID: Summrs International
#
# Song Name: 46
# Artist: Chloe Kelly
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 18
# Artist: The Strange and the Kind - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 15
# Artist: Rivers Edge - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 19
# Artist: All Is Lost - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 16
# Artist: Fire Walk with Me - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 14
# Artist: It Followed Me - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 21
# Artist: Doom Generation - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 24
# Artist: The Strange and the Kind - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 17
# Artist: Rivers Edge - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 27
# Artist: All Is Lost - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 21
# Artist: Fire Walk with Me - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 17
# Artist: It Followed Me - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 39
# Artist: Reality Bytes
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 36
# Artist: Beach Whatever
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 58
# Artist: I'm Not Making out With You
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 35
# Artist: Haunt Me
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 33
# Artist: Skullder
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 54
# Artist: Forever Dumb
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 1
# Artist: Freaks
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 1
# Artist: Freaks
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 38
# Artist: Velour
# Similarity: 149.0
# Track ID: TEK.LUN
#
# Song Name: 16
# Artist: SPEEDIN
# Similarity: 149.0
# Track ID: TINY TAPES
#
# Song Name: 54
# Artist: The Night in Question
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 59
# Artist: Valerie
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 45
# Artist: Lines to a Different Play
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 71
# Artist: It Almost Worked
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 52
# Artist: The Desolation Tango
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 54
# Artist: Sleeping with the Enemy
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 47
# Artist: Your Friends Are Calling Your Name
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 54
# Artist: Stay Away (It's Like That)
# Similarity: 149.0
# Track ID: TV Girl
#
# Song Name: 16
# Artist: Doom Generation - Audiotree Live Version
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 71
# Artist: Disco
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 22
# Artist: Midnight Cowboy
# Similarity: 149.0
# Track ID: Surf Curse
#
# Song Name: 46
# Artist: Self Portrait
# Similarity: 149.0
# Track ID: Surf Curse
